# %% [markdown]
# <a href="https://colab.research.google.com/github/ilyademichev1902/test/blob/main/NY_fs_methods_classification_attempt.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# prompt: attach google drive folder to read the dataset

from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# prompt: read csv file "cny.csv"

import pandas as pd

df = pd.read_csv('/content/drive/My Drive/datascience/NYPD_Complaint_Data_Current__Year_To_Date_better.csv')
df.head()
# Out:
# <ipython-input-2-cce5586360c3>:5: DtypeWarning: Columns (0) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('/content/drive/My Drive/datascience/NYPD_Complaint_Data_Current__Year_To_Date_better.csv')
#   CMPLNT_NUM  ADDR_PCT_CD        BORO_NM CMPLNT_FR_DT CMPLNT_FR_TM  \
# 0  280510523           14      MANHATTAN   01/11/2024     04:00:00
# 1  286736978          122  STATEN ISLAND   01/01/2015     13:00:00
# 2  289019347            1      MANHATTAN   06/20/2024     16:12:00
# 3  283688417          121  STATEN ISLAND   03/11/2024     10:00:00
# 4  280934552          122  STATEN ISLAND   11/14/2023     12:00:00
#
#   CMPLNT_TO_DT CMPLNT_TO_TM CRM_ATPT_CPTD_CD HADEVELOPT  HOUSING_PSA  ...  \
# 0          NaN       (null)        COMPLETED     (null)          NaN  ...
# 1   01/01/2015     15:00:00        COMPLETED     (null)          NaN  ...
# 2   06/20/2024     16:13:00        COMPLETED     (null)          NaN  ...
# ...

# %%
# prompt: print number of rows in df dataframe

print("Rows total:",len(df))
# Out:
# Rows total: 282069

# %%
# prompt: replace values of (null) by NaN in df dataset
print("Before replacing\nAmount of missed values:\n")
print(df.isna().sum())
#df.head()
# Out:
# Before replacing
# Amount of missed values:
#
# CMPLNT_NUM                       0
# ADDR_PCT_CD                      0
# BORO_NM                          0
# CMPLNT_FR_DT                     0
# CMPLNT_FR_TM                     0
# CMPLNT_TO_DT                 14883
# CMPLNT_TO_TM                     0
# CRM_ATPT_CPTD_CD                 0
# HADEVELOPT                       0
# HOUSING_PSA                 264419
# JURISDICTION_CODE                0
# JURIS_DESC                       0
# KY_CD                            0
# LAW_CAT_CD                       0
# LOC_OF_OCCUR_DESC                0
# OFNS_DESC                        0
# PARKS_NM                         0
# PATROL_BORO                      0
# PD_CD                          172
# PD_DESC                          0
# PREM_TYP_DESC                    0
# RPT_DT                           0
# STATION_NAME                     0
# SUSP_AGE_GROUP                   0
# SUSP_RACE                        0
# ...

# %%
#replace text nulls
df.replace('(null)', pd.NA, inplace=True)
df.head()
# Out:
#   CMPLNT_NUM  ADDR_PCT_CD        BORO_NM CMPLNT_FR_DT CMPLNT_FR_TM  \
# 0  280510523           14      MANHATTAN   01/11/2024     04:00:00
# 1  286736978          122  STATEN ISLAND   01/01/2015     13:00:00
# 2  289019347            1      MANHATTAN   06/20/2024     16:12:00
# 3  283688417          121  STATEN ISLAND   03/11/2024     10:00:00
# 4  280934552          122  STATEN ISLAND   11/14/2023     12:00:00
#
#   CMPLNT_TO_DT CMPLNT_TO_TM CRM_ATPT_CPTD_CD HADEVELOPT  HOUSING_PSA  ...  \
# 0          NaN         <NA>        COMPLETED       <NA>          NaN  ...
# 1   01/01/2015     15:00:00        COMPLETED       <NA>          NaN  ...
# 2   06/20/2024     16:13:00        COMPLETED       <NA>          NaN  ...
# 3   03/13/2024     13:20:00        COMPLETED       <NA>          NaN  ...
# 4   11/17/2023     12:00:00        COMPLETED       <NA>          NaN  ...
#
#    TRANSIT_DISTRICT VIC_AGE_GROUP  VIC_RACE VIC_SEX X_COORD_CD Y_COORD_CD  \
# ...

# %%
#replace text NaNs
import numpy as np
df.replace('NaN', pd.NA, inplace=True)
print("After text null and Nan replacing into pandas.NaN:")
df.replace(np.nan, pd.NA, inplace=True)

print(df.isna().sum())
# Out:
# After text null and Nan replacing into pandas.NaN:
# CMPLNT_NUM                       0
# ADDR_PCT_CD                      0
# BORO_NM                        150
# CMPLNT_FR_DT                     0
# CMPLNT_FR_TM                     0
# CMPLNT_TO_DT                 14883
# CMPLNT_TO_TM                 14671
# CRM_ATPT_CPTD_CD                 0
# HADEVELOPT                  281219
# HOUSING_PSA                 264419
# JURISDICTION_CODE                0
# JURIS_DESC                       0
# KY_CD                            0
# LAW_CAT_CD                       0
# LOC_OF_OCCUR_DESC            60868
# OFNS_DESC                        5
# PARKS_NM                    280551
# PATROL_BORO                      0
# PD_CD                          172
# PD_DESC                        172
# PREM_TYP_DESC                12573
# RPT_DT                           0
# STATION_NAME                269621
# SUSP_AGE_GROUP               31808
# SUSP_RACE                    31808
# ...

# %%
# prompt: list columns by index
threshold = 90
threshold_number = int(len(df) * threshold/100)
print("\n".join([str(num)+":"+str(col)+" missing" if int(col)>threshold_number else str(num)+":"+">"+str(threshold)+"% present" for num,col in enumerate(df.isna().sum())]))
# Out:
# 0:>90% present
# 1:>90% present
# 2:>90% present
# 3:>90% present
# 4:>90% present
# 5:>90% present
# 6:>90% present
# 7:>90% present
# 8:281219 missing
# 9:264419 missing
# 10:>90% present
# 11:>90% present
# 12:>90% present
# 13:>90% present
# 14:>90% present
# 15:>90% present
# 16:280551 missing
# 17:>90% present
# 18:>90% present
# 19:>90% present
# 20:>90% present
# 21:>90% present
# 22:269621 missing
# 23:>90% present
# 24:>90% present
# 25:>90% present
# 26:269621 missing
# 27:>90% present
# 28:>90% present
# 29:>90% present
# 30:>90% present
# 31:>90% present
# 32:>90% present
# 33:>90% present
# 34:>90% present
# 35:>90% present

# %%
# prompt: eliminate from df dataframe columns 35 and 36

#df = df.drop(df.columns[[8,9,16, 41]], axis=1)
#df = df.drop(df.columns[list(range(20,38))], axis=1)
df = df.drop(df.columns[[8,9,16,22,26]], axis=1)

# %%
# prompt: drop last column

#df = df.iloc[:, :-1]

# %%
# prompt: eliminate TRANSIT_DISTRICT column

#df = df.drop('TRANSIT_DISTRICT', axis=1)
#df = df.drop('STATION_NAME', axis=1)
#print("After dropping missed and 95% missed columns:",df.isnull().sum())

# %%
#df.dropna(inplace=True)
#df = df.drop('Unnamed: 40', axis=1)
print("After dropping columns with less than {}% data present ,still missing".format(threshold))
print(df.isna().sum())
# Out:
# After dropping columns with less than 90% data present ,still missing
# CMPLNT_NUM                      0
# ADDR_PCT_CD                     0
# BORO_NM                       150
# CMPLNT_FR_DT                    0
# CMPLNT_FR_TM                    0
# CMPLNT_TO_DT                14883
# CMPLNT_TO_TM                14671
# CRM_ATPT_CPTD_CD                0
# JURISDICTION_CODE               0
# JURIS_DESC                      0
# KY_CD                           0
# LAW_CAT_CD                      0
# LOC_OF_OCCUR_DESC           60868
# OFNS_DESC                       5
# PATROL_BORO                     0
# PD_CD                         172
# PD_DESC                       172
# PREM_TYP_DESC               12573
# RPT_DT                          0
# SUSP_AGE_GROUP              31808
# SUSP_RACE                   31808
# SUSP_SEX                    31808
# VIC_AGE_GROUP                   0
# VIC_RACE                       14
# VIC_SEX                         0
# ...

# %%
#print("Rows total:",len(df))
df.head()
# Out:
#   CMPLNT_NUM  ADDR_PCT_CD        BORO_NM CMPLNT_FR_DT CMPLNT_FR_TM  \
# 0  280510523           14      MANHATTAN   01/11/2024     04:00:00
# 1  286736978          122  STATEN ISLAND   01/01/2015     13:00:00
# 2  289019347            1      MANHATTAN   06/20/2024     16:12:00
# 3  283688417          121  STATEN ISLAND   03/11/2024     10:00:00
# 4  280934552          122  STATEN ISLAND   11/14/2023     12:00:00
#
#   CMPLNT_TO_DT CMPLNT_TO_TM CRM_ATPT_CPTD_CD  JURISDICTION_CODE  \
# 0         <NA>         <NA>        COMPLETED                  0
# 1   01/01/2015     15:00:00        COMPLETED                  0
# 2   06/20/2024     16:13:00        COMPLETED                  1
# 3   03/13/2024     13:20:00        COMPLETED                  0
# 4   11/17/2023     12:00:00        COMPLETED                  0
#
#             JURIS_DESC  ...  SUSP_SEX VIC_AGE_GROUP VIC_RACE VIC_SEX  \
# 0     N.Y. POLICE DEPT  ...         U         18-24    BLACK       F
# ...

# %%
# prompt: replace numpy NaN with pandas NaN , drop rows that contain pandas NaN

# Drop rows with pandas NaN
before_dropna = df.copy(deep=True)
df.dropna(inplace=True)

# %%
print("After dropping all the rest of missing values".format(threshold))
print(df.isna().sum())
# Out:
# After dropping all the rest of missing values
# CMPLNT_NUM                  0
# ADDR_PCT_CD                 0
# BORO_NM                     0
# CMPLNT_FR_DT                0
# CMPLNT_FR_TM                0
# CMPLNT_TO_DT                0
# CMPLNT_TO_TM                0
# CRM_ATPT_CPTD_CD            0
# JURISDICTION_CODE           0
# JURIS_DESC                  0
# KY_CD                       0
# LAW_CAT_CD                  0
# LOC_OF_OCCUR_DESC           0
# OFNS_DESC                   0
# PATROL_BORO                 0
# PD_CD                       0
# PD_DESC                     0
# PREM_TYP_DESC               0
# RPT_DT                      0
# SUSP_AGE_GROUP              0
# SUSP_RACE                   0
# SUSP_SEX                    0
# VIC_AGE_GROUP               0
# VIC_RACE                    0
# VIC_SEX                     0
# X_COORD_CD                  0
# Y_COORD_CD                  0
# Latitude                    0
# Longitude                   0
# ...

# %%
print("Data rows left")
print(len(df))
# Out:
# Data rows left
# 179650

# %%
# prompt: find unique values of field JURISDICTION_CODE and number of each of them

unique_values = df['JURISDICTION_CODE'].value_counts()
print(unique_values)
# Out:
# JURISDICTION_CODE
# 0     162963
# 2      15143
# 3        496
# 17       472
# 97       224
# 51        80
# 14        58
# 72        46
# 87        39
# 73        31
# 7         27
# 88        18
# 4         15
# 52        12
# 11        12
# 13         6
# 12         4
# 76         3
# 85         1
# Name: count, dtype: int64

# %%
#print amount of unique values for each column
print("Unnique values for each column\n")
print(df.nunique())
# Out:
# Unnique values for each column
#
# CMPLNT_NUM                  179650
# ADDR_PCT_CD                     77
# BORO_NM                          5
# CMPLNT_FR_DT                  1245
# CMPLNT_FR_TM                  1440
# CMPLNT_TO_DT                   910
# CMPLNT_TO_TM                  1440
# CRM_ATPT_CPTD_CD                 2
# JURISDICTION_CODE               19
# JURIS_DESC                      19
# KY_CD                           63
# LAW_CAT_CD                       3
# LOC_OF_OCCUR_DESC                4
# OFNS_DESC                       59
# PATROL_BORO                      8
# PD_CD                          342
# PD_DESC                        332
# PREM_TYP_DESC                   77
# RPT_DT                         182
# SUSP_AGE_GROUP                  18
# SUSP_RACE                        7
# SUSP_SEX                         3
# VIC_AGE_GROUP                   18
# VIC_RACE                         7
# VIC_SEX                          5
# X_COORD_CD                   29537
# ...

# %%
# prompt: drop columns in range 22-25

#df = df.drop(df.columns[list(range(0,2))], axis=1)
#df.head()

# %%
# prompt: drop columns from ['JURISDICTION_CODE', 'PD_CD','CMPLNT_NUM','KY_CD'] if exist
# display the head

# Drop columns if they exist
for col in ['JURISDICTION_CODE', 'PD_CD','CMPLNT_NUM','KY_CD','ADDR_PCT_CD','PATROL_BORO','JURIS_DESC']:
  if col in df.columns:
    df = df.drop(col, axis=1)

# %%
# Display the head

df.head()
# Out:
#           BORO_NM CMPLNT_FR_DT CMPLNT_FR_TM CMPLNT_TO_DT CMPLNT_TO_TM  \
# 1   STATEN ISLAND   01/01/2015     13:00:00   01/01/2015     15:00:00
# 8       MANHATTAN   01/03/2024     22:18:00   01/03/2024     23:25:00
# 9   STATEN ISLAND   01/19/2024     18:00:00   01/19/2024     23:00:00
# 10  STATEN ISLAND   01/03/2024     17:40:00   01/03/2024     17:42:00
# 11      MANHATTAN   02/07/2024     19:30:00   02/07/2024     19:45:00
#
#    CRM_ATPT_CPTD_CD   LAW_CAT_CD LOC_OF_OCCUR_DESC  \
# 1         COMPLETED  MISDEMEANOR            INSIDE
# 8         COMPLETED       FELONY          FRONT OF
# 9         COMPLETED  MISDEMEANOR            INSIDE
# 10        COMPLETED  MISDEMEANOR          FRONT OF
# 11        COMPLETED  MISDEMEANOR          FRONT OF
#
#                          OFNS_DESC                         PD_DESC  ...  \
# 1                       SEX CRIMES                SEXUAL ABUSE 3,2  ...
# 8   GRAND LARCENY OF MOTOR VEHICLE           LARCENY,GRAND OF AUTO  ...
# ...

# %%
# prompt: number of unique values for each column , display unique values if amount is less than 5
categorical = {}
for col in df.columns:
  unique_vals = df[col].unique()
  num_unique = len(unique_vals)
  #print(f"Column '{col}': {num_unique} unique values")
  if num_unique <= 5:
    categorical[col] = unique_vals
    #print(f"{col}:15: {unique_vals}")

# %%
# prompt:  print a dictionary categorical in a  table , each column with increasing number of values

import pandas as pd

# Create a DataFrame from the dictionary
df_categorical = pd.DataFrame.from_dict(categorical, orient='index').transpose()

# Sort columns by the number of unique values
df_categorical = df_categorical.reindex(sorted(df_categorical.columns, key=lambda col: df_categorical[col].nunique()), axis=1)

# Display the DataFrame as a table
df_categorical
# Out:
#   CRM_ATPT_CPTD_CD   LAW_CAT_CD SUSP_SEX LOC_OF_OCCUR_DESC        BORO_NM  \
# 0        COMPLETED  MISDEMEANOR        M            INSIDE  STATEN ISLAND
# 1        ATTEMPTED       FELONY        U          FRONT OF      MANHATTAN
# 2             None    VIOLATION        F       OPPOSITE OF       BROOKLYN
# 3             None         None     None           REAR OF          BRONX
# 4             None         None     None              None         QUEENS
#
#   VIC_SEX
# 0       F
# 1       M
# 2       D
# 3       E
# 4       L

# %%
before_labeling = df.copy(deep=True)

# %%
# prompt: drop last  6 columns

df = df.iloc[:, :-6]

# %%
# prompt: remove columns begining with SUSP and apply labelencoder to all columns except  LAW_CAT_CD and VIC_AGE_GROUP

from sklearn.preprocessing import LabelEncoder

# Remove columns starting with 'SUSP'
df = df.loc[:, ~df.columns.str.startswith('SUSP')]

# Apply LabelEncoder to all columns except 'LAW_CAT_CD' and 'VIC_AGE_GROUP'
le = LabelEncoder()
for column in df.columns:
  if column not in ['LAW_CAT_CD', 'VIC_AGE_GROUP']:
    if df[column].dtype == object:
      df[column] = le.fit_transform(df[column])
# Out:
# <ipython-input-25-fb73d9b80767>:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[column] = le.fit_transform(df[column])
# <ipython-input-25-fb73d9b80767>:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[column] = le.fit_transform(df[column])

# %%
df.head()
# Out:
#     BORO_NM  CMPLNT_FR_DT  CMPLNT_FR_TM  CMPLNT_TO_DT  CMPLNT_TO_TM  \
# 1         4            23           780             5           900
# 8         2            41          1338            17          1405
# 9         4            98          1080            58          1380
# 10        4            41          1060            17          1062
# 11        2           174          1170           112          1185
#
#     CRM_ATPT_CPTD_CD   LAW_CAT_CD  LOC_OF_OCCUR_DESC  OFNS_DESC  PD_DESC  \
# 1                  1  MISDEMEANOR                  1         53      296
# 8                  1       FELONY                  0         26      170
# 9                  1  MISDEMEANOR                  1         38        8
# 10                 1  MISDEMEANOR                  0         58      198
# 11                 1  MISDEMEANOR                  0         47      188
#
#     PREM_TYP_DESC  RPT_DT VIC_AGE_GROUP  VIC_RACE  VIC_SEX
# ...

# %%
# prompt: drop columns starting from CMPLNT

# Remove columns starting with 'CMPLNT'
df = df.loc[:, ~df.columns.str.startswith('CMPLNT')]

# %%
# prompt: manually encode LAW_CAT_CD , VIC_AGE_GROUP

# Manually encode 'LAW_CAT_CD'
law_cat_mapping = {
    'FELONY': 2,
    'MISDEMEANOR': 1,
    'VIOLATION': 0
}
df['LAW_CAT_CD'] = df['LAW_CAT_CD'].map(law_cat_mapping)

# Manually encode 'VIC_AGE_GROUP'
vic_age_mapping = {
    '<18': 0,
    '18-24': 1,
    '25-44': 2,
    '45-64': 3,
    '65+': 4
}
df['VIC_AGE_GROUP'] = df['VIC_AGE_GROUP'].map(vic_age_mapping)

df.head()
# Out:
# <ipython-input-28-8361600ed9ad>:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['LAW_CAT_CD'] = df['LAW_CAT_CD'].map(law_cat_mapping)
# <ipython-input-28-8361600ed9ad>:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['VIC_AGE_GROUP'] = df['VIC_AGE_GROUP'].map(vic_age_mapping)
#     BORO_NM  CRM_ATPT_CPTD_CD  LAW_CAT_CD  LOC_OF_OCCUR_DESC  OFNS_DESC  \
# 1         4                 1           1                  1         53
# ...

# %%
# prompt: show values distribution for VIC_AGE_GROUP with missed and NaN values

# Assuming 'before_dropna' DataFrame still contains the original data with missing values
print(df['VIC_AGE_GROUP'].value_counts(dropna=False))
# Out:
# VIC_AGE_GROUP
# 2.0    65351
# NaN    49067
# 3.0    32750
# 1.0    15441
# 4.0     9090
# 0.0     7951
# Name: count, dtype: int64

# %%
# prompt: drop all UNKNOWN values from VIC_AGE_GROUP,  try to convert each row into integer, drop the row if  the number value is  negative or above 900, otherwise leave intact

# Drop rows where 'VIC_AGE_GROUP' is 'UNKNOWN'
df = df[df['VIC_AGE_GROUP'] != 'UNKNOWN']

# Attempt to convert 'VIC_AGE_GROUP' to integer and handle errors
def convert_to_int_and_filter(value):
  try:
    int_value = int(value)
    if 0 <= int_value <= 900:
      return value
    else:
      return None  # Replace with None or another appropriate value
  except (ValueError, TypeError):
    return value  # Replace with None or another appropriate value

df['VIC_AGE_GROUP'] = df['VIC_AGE_GROUP'].apply(convert_to_int_and_filter)

# Drop rows with None values in 'VIC_AGE_GROUP' (resulting from filtering)
df.dropna(subset=['VIC_AGE_GROUP'], inplace=True)

# Convert 'VIC_AGE_GROUP' to integer type
df['VIC_AGE_GROUP'] = df['VIC_AGE_GROUP'].astype(int)

df.head()
# Out:
#     BORO_NM  CRM_ATPT_CPTD_CD  LAW_CAT_CD  LOC_OF_OCCUR_DESC  OFNS_DESC  \
# 1         4                 1           1                  1         53
# 8         2                 1           2                  0         26
# 9         4                 1           1                  1         38
# 10        4                 1           1                  0         58
# 13        2                 1           2                  1         18
#
#     PD_DESC  PREM_TYP_DESC  RPT_DT  VIC_AGE_GROUP  VIC_RACE  VIC_SEX
# 1       296             58     131              2         4        2
# 8       170             46       3              2         2        4
# 9         8             58      19              3         5        4
# 10      198             66       2              4         5        2
# 13      308             42     166              1         6        2

# %%
# prompt: print  the distribution of values in VIC_AGE_GROUP with missed values

print(df['VIC_AGE_GROUP'].value_counts(dropna=False))
df.head()
# Out:
# VIC_AGE_GROUP
# 2    65351
# 3    32750
# 1    15441
# 4     9090
# 0     7951
# Name: count, dtype: int64
#     BORO_NM  CRM_ATPT_CPTD_CD  LAW_CAT_CD  LOC_OF_OCCUR_DESC  OFNS_DESC  \
# 1         4                 1           1                  1         53
# 8         2                 1           2                  0         26
# 9         4                 1           1                  1         38
# 10        4                 1           1                  0         58
# 13        2                 1           2                  1         18
#
#     PD_DESC  PREM_TYP_DESC  RPT_DT  VIC_AGE_GROUP  VIC_RACE  VIC_SEX
# 1       296             58     131              2         4        2
# 8       170             46       3              2         2        4
# 9         8             58      19              3         5        4
# 10      198             66       2              4         5        2
# 13      308             42     166              1         6        2

# %%
# prompt:   encode OFNS_DESC with labelencoder specify CRM_ATPT_CPTD_CD as a target variable and others as predictors

# Apply LabelEncoder to 'OFNS_DESC'
simple_offense_description = df.drop('PD_DESC',axis=1)
extended_offense_description = df.drop('OFNS_DESC',axis=1)
without_offense_description = df.drop(['PD_DESC','OFNS_DESC'],axis=1)
#label_encoder = LabelEncoder()
#simple_offense_description['OFNS_DESC'] = label_encoder.fit_transform(simple_offense_description['OFNS_DESC'])

without_offense_description.head()
# Out:
#     BORO_NM  CRM_ATPT_CPTD_CD  LAW_CAT_CD  LOC_OF_OCCUR_DESC  PREM_TYP_DESC  \
# 1         4                 1           1                  1             58
# 8         2                 1           2                  0             46
# 9         4                 1           1                  1             58
# 10        4                 1           1                  0             66
# 13        2                 1           2                  1             42
#
#     RPT_DT  VIC_AGE_GROUP  VIC_RACE  VIC_SEX
# 1      131              2         4        2
# 8        3              2         2        4
# 9       19              3         5        4
# 10       2              4         5        2
# 13     166              1         6        2

# %%
# prompt: drop VIC_RACE

# Assuming 'df' is your DataFrame
if 'VIC_RACE' in df.columns:
  df = df.drop('VIC_RACE', axis=1)
df.head()
# Out:
#     BORO_NM  CRM_ATPT_CPTD_CD  LAW_CAT_CD  LOC_OF_OCCUR_DESC  OFNS_DESC  \
# 1         4                 1           1                  1         53
# 8         2                 1           2                  0         26
# 9         4                 1           1                  1         38
# 10        4                 1           1                  0         58
# 13        2                 1           2                  1         18
#
#     PD_DESC  PREM_TYP_DESC  RPT_DT  VIC_AGE_GROUP  VIC_SEX
# 1       296             58     131              2        2
# 8       170             46       3              2        4
# 9         8             58      19              3        4
# 10      198             66       2              4        2
# 13      308             42     166              1        2

# %%
# prompt: drop PD_DESC,PREM_TYP_DESC,RPT_DT

# Assuming 'df' is your DataFrame
columns_to_drop = ['PD_DESC', 'PREM_TYP_DESC', 'RPT_DT']
for column in columns_to_drop:
  if column in df.columns:
    df = df.drop(column, axis=1)

df.head()
# Out:
#     BORO_NM  CRM_ATPT_CPTD_CD  LAW_CAT_CD  LOC_OF_OCCUR_DESC  OFNS_DESC  \
# 1         4                 1           1                  1         53
# 8         2                 1           2                  0         26
# 9         4                 1           1                  1         38
# 10        4                 1           1                  0         58
# 13        2                 1           2                  1         18
#
#     VIC_AGE_GROUP  VIC_SEX
# 1               2        2
# 8               2        4
# 9               3        4
# 10              4        2
# 13              1        2

# %%
# prompt: drop OFNS_DESC

if 'OFNS_DESC' in df.columns:
  df = df.drop('OFNS_DESC', axis=1)
df.head()
# Out:
#     BORO_NM  CRM_ATPT_CPTD_CD  LAW_CAT_CD  LOC_OF_OCCUR_DESC  VIC_AGE_GROUP  \
# 1         4                 1           1                  1              2
# 8         2                 1           2                  0              2
# 9         4                 1           1                  1              3
# 10        4                 1           1                  0              4
# 13        2                 1           2                  1              1
#
#     VIC_SEX
# 1         2
# 8         4
# 9         4
# 10        2
# 13        2

# %%
# prompt:  Count amount of each unique value for each column in df and show the distributions graphically as small plots close to each other 3 plots on each line

import matplotlib.pyplot as plt

# Calculate the number of unique values for each column
unique_counts = df.nunique()

# Create a figure and axes for the subplots
num_cols = 3
num_rows = (len(unique_counts) + num_cols - 1) // num_cols
fig, axes = plt.subplots(num_rows, num_cols, figsize=(15, 5 * num_rows))

# Iterate through the columns and create a plot for each
for i, (column, count) in enumerate(unique_counts.items()):
    row = i // num_cols
    col = i % num_cols

    # Create a bar plot for the unique value counts
    value_counts = df[column].value_counts()
    axes[row, col].bar(value_counts.index, value_counts.values)
    axes[row, col].set_title(f"Column: {column}")
    axes[row, col].tick_params(axis='x', rotation=45, labelsize=8)

    # Remove extra subplots if necessary
    if i >= len(unique_counts) - 1:
        for j in range(i + 1, num_rows * num_cols):
            row_extra = j // num_cols
            col_extra = j % num_cols
            fig.delaxes(axes[row_extra, col_extra])

# Adjust the layout and display the plots
plt.tight_layout()
plt.show()

# %%
# prompt: drop rows where VIC_SEX is 0,1 or 2

# Drop rows where 'VIC_SEX' is 0, 1, or 2
df = df[~df['VIC_SEX'].isin([0, 1, 3])]

# %%
# Count amount of each unique value for each column in X
for col in df.columns:
  unique_values_count = df[col].value_counts()
  print(f"Unique values count for column '{col}':\n{unique_values_count}\n")
# Out:
# Unique values count for column 'BORO_NM':
# BORO_NM
# 1    37709
# 3    30151
# 0    27835
# 2    27671
# 4     6275
# Name: count, dtype: int64
#
# Unique values count for column 'CRM_ATPT_CPTD_CD':
# CRM_ATPT_CPTD_CD
# 1    127660
# 0      1981
# Name: count, dtype: int64
#
# Unique values count for column 'LAW_CAT_CD':
# LAW_CAT_CD
# 1    54811
# 2    43245
# 0    31585
# Name: count, dtype: int64
#
# Unique values count for column 'LOC_OF_OCCUR_DESC':
# LOC_OF_OCCUR_DESC
# 1    84347
# 0    40662
# 2     2492
# 3     2140
# Name: count, dtype: int64
#
# Unique values count for column 'VIC_AGE_GROUP':
# VIC_AGE_GROUP
# 2    64623
# 3    32670
# 1    15318
# 4     9085
# 0     7945
# Name: count, dtype: int64
#
# Unique values count for column 'VIC_SEX':
# VIC_SEX
# 2    71932
# 4    57709
# Name: count, dtype: int64

# %%
# Specify target variable and predictors
#df.head()
X = df.drop('LAW_CAT_CD', axis=1)  # Predictors
y = df['LAW_CAT_CD']  # Target variable

# %%
X.head()
# Out:
#     BORO_NM  CRM_ATPT_CPTD_CD  LOC_OF_OCCUR_DESC  VIC_AGE_GROUP  VIC_SEX
# 1         4                 1                  1              2        2
# 8         2                 1                  0              2        4
# 9         4                 1                  1              3        4
# 10        4                 1                  0              4        2
# 13        2                 1                  1              1        2

# %%
# prompt: count amount of each unique value for y

unique_values_count = y.value_counts()
print(unique_values_count)
print(X.columns)
# Out:
# LAW_CAT_CD
# 1    54811
# 2    43245
# 0    31585
# Name: count, dtype: int64
# Index(['BORO_NM', 'CRM_ATPT_CPTD_CD', 'LOC_OF_OCCUR_DESC', 'VIC_AGE_GROUP',
#        'VIC_SEX'],
#       dtype='object')

# %%
from sklearn.svm import LinearSVC
from sklearn.feature_selection import SelectFromModel

# print("before LinearSVC:")
# print(X.shape)
lsvc = LinearSVC(C=0.01, penalty="l1", dual=False).fit(X, y)
model = SelectFromModel(lsvc, prefit=True)
X_lsvc = model.transform(X)
# Get the indices of the selected features
selected_features_indices = model.get_support(indices=True)
# Get the names of the selected features
selected_features = X.columns[selected_features_indices]
# print("after LinearSVC:")
# print(X_lsvc.shape)

print("Selected features:", list(selected_features))
print("Eliminated features:", list(set(X.columns)-set(selected_features)))
# Print the shape of the original and selected data
print("Original data shape:", X.shape)
print("Selected data shape:", X_lsvc.shape)
# Out:
# Selected features: ['BORO_NM', 'CRM_ATPT_CPTD_CD', 'LOC_OF_OCCUR_DESC', 'VIC_AGE_GROUP', 'VIC_SEX']
# Eliminated features: []
# Original data shape: (129641, 5)
# Selected data shape: (129641, 5)
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:458: UserWarning: X has feature names, but SelectFromModel was fitted without feature names
#   warnings.warn(

# %%
from sklearn.ensemble import ExtraTreesClassifier
from sklearn.feature_selection import SelectFromModel
#X, y = load_iris(return_X_y=True)
clf = ExtraTreesClassifier(n_estimators=50)
clf = clf.fit(X, y)
clf.feature_importances_
model = SelectFromModel(clf, prefit=True)
X_etc = model.transform(X)

# Get the indices of the selected features
selected_features_indices = model.get_support(indices=True)
# Get the names of the selected features
selected_features = X.columns[selected_features_indices]
# print("after LinearSVC:")
# print(X_lsvc.shape)

print("Selected features:", list(selected_features))
print("Eliminated features:", list(set(X.columns)-set(selected_features)))
# Print the shape of the original and selected data
print("Original data shape:", X.shape)
print("Selected data shape:", X_etc.shape)
# Out:
# Selected features: ['CRM_ATPT_CPTD_CD', 'LOC_OF_OCCUR_DESC', 'VIC_AGE_GROUP']
# Eliminated features: ['BORO_NM', 'VIC_SEX']
# Original data shape: (129641, 5)
# Selected data shape: (129641, 3)
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:458: UserWarning: X has feature names, but SelectFromModel was fitted without feature names
#   warnings.warn(

# %%
# prompt: use feature selection based on SelectKBest , print out selected feature names

from sklearn.feature_selection import SelectKBest, f_classif, chi2

# Assuming X and y are defined as in your previous code

# Select the top 10 features based on given statistic
selector = SelectKBest(chi2, k=3)
X_kbest = selector.fit_transform(X, y)

# Get the indices of the selected features
selected_features_indices = selector.get_support(indices=True)

# Get the names of the selected features
selected_features = X.columns[selected_features_indices]

print("Selected features:", list(selected_features))
print("Eliminated features:", list(set(X.columns)-set(selected_features)))
# Print the shape of the original and selected data
print("Original data shape:", X.shape)
print("Selected data shape:", X_kbest.shape)
# Out:
# Selected features: ['LOC_OF_OCCUR_DESC', 'VIC_AGE_GROUP', 'VIC_SEX']
# Eliminated features: ['CRM_ATPT_CPTD_CD', 'BORO_NM']
# Original data shape: (129641, 5)
# Selected data shape: (129641, 3)

# %%
# prompt: apply from SequentialFeatureSelector to select features of X to targey y, use forward and backward methods, print selected and eliminated features , use ridge regression, specify num_fs variable for desired number of features

from sklearn.linear_model import Ridge
from sklearn.feature_selection import SequentialFeatureSelector

num_fs = 2  # Desired number of features

# Forward selection
ridge = Ridge()
sfs_forward = SequentialFeatureSelector(ridge, n_features_to_select=num_fs, direction='forward')
sfs_forward.fit(X, y)
selected_features_forward = X.columns[sfs_forward.get_support()]
eliminated_features_forward = list(set(X.columns) - set(selected_features_forward))

print("Forward Selection Ridge Regression:")
print("Selected features:", list(selected_features_forward))
print("Eliminated features:", eliminated_features_forward)

# Backward selection
sfs_backward = SequentialFeatureSelector(ridge, n_features_to_select=num_fs, direction='backward')
sfs_backward.fit(X, y)
selected_features_backward = X.columns[sfs_backward.get_support()]
eliminated_features_backward = list(set(X.columns) - set(selected_features_backward))

print("\nBackward Selection Ridge Regression:")
print("Selected features:", list(selected_features_backward))
print("Eliminated features:", eliminated_features_backward)
# Out:
# Forward Selection Ridge Regression:
# Selected features: ['CRM_ATPT_CPTD_CD', 'VIC_SEX']
# Eliminated features: ['BORO_NM', 'LOC_OF_OCCUR_DESC', 'VIC_AGE_GROUP']
#
# Backward Selection Ridge Regression:
# Selected features: ['CRM_ATPT_CPTD_CD', 'VIC_SEX']
# Eliminated features: ['BORO_NM', 'LOC_OF_OCCUR_DESC', 'VIC_AGE_GROUP']

# %%
# prompt: apply from SequentialFeatureSelector to select features of X to targey y, use forward and backward methods, print selected and eliminated features , use logistic regression, specify num_fs variable for desired number of features

from sklearn.linear_model import LogisticRegression
from sklearn.feature_selection import SequentialFeatureSelector

num_fs = 2  # Desired number of features

# Forward selection
logreg = LogisticRegression(max_iter=1000)  # Increase max_iter if needed
sfs_forward = SequentialFeatureSelector(logreg, n_features_to_select=num_fs, direction='forward')
sfs_forward.fit(X, y)
selected_features_forward = X.columns[sfs_forward.get_support()]
eliminated_features_forward = list(set(X.columns) - set(selected_features_forward))

print("Forward Selection Logistic Regression:")
print("Selected features:", list(selected_features_forward))
print("Eliminated features:", eliminated_features_forward)

# Backward selection
sfs_backward = SequentialFeatureSelector(logreg, n_features_to_select=num_fs, direction='backward')
sfs_backward.fit(X, y)
selected_features_backward = X.columns[sfs_backward.get_support()]
eliminated_features_backward = list(set(X.columns) - set(selected_features_backward))

print("\nBackward Selection Logistic Regression:")
print("Selected features:", list(selected_features_backward))
print("Eliminated features:", eliminated_features_backward)
# Out:
# Forward Selection Logistic Regression:
# Selected features: ['CRM_ATPT_CPTD_CD', 'VIC_AGE_GROUP']
# Eliminated features: ['BORO_NM', 'LOC_OF_OCCUR_DESC', 'VIC_SEX']
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-46-f739cc25b5e2> in <cell line: 21>()
#      19 # Backward selection
#      20 sfs_backward = SequentialFeatureSelector(logreg, n_features_to_select=num_fs, direction='backward')
# ---> 21 sfs_backward.fit(X, y)
#      22 selected_features_backward = X.columns[sfs_backward.get_support()]
#      23 eliminated_features_backward = list(set(X.columns) - set(selected_features_backward))
#
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py in wrapper(estimator, *args, **kwargs)
#    1150                 )
#    1151             ):
# -> 1152                 return fit_method(estimator, *args, **kwargs)
#    1153
#    1154         return wrapper
#
# ...

# %%
# prompt: select features of  ['VIC_AGE_GROUP', 'VIC_SEX', 'LOC_OF_OCCUR_DESC'] into X_sf

#X_sf = X[['VIC_AGE_GROUP', 'VIC_SEX', 'LOC_OF_OCCUR_DESC']]
X_sf = X[[ 'LOC_OF_OCCUR_DESC']]

# %%
# prompt: print distribution of number of unique values for each feature of X_sf

for column in X_sf.columns:
  unique_counts = X_sf[column].value_counts()
  print(f"Distribution of unique values for '{column}':\n{unique_counts}\n")
# Out:
# Distribution of unique values for 'LOC_OF_OCCUR_DESC':
# LOC_OF_OCCUR_DESC
# 1    84347
# 0    40662
# 2     2492
# 3     2140
# Name: count, dtype: int64

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X_sf, y, test_size=0.3, random_state=42)

# %%
# prompt: split into training and test ,learn a neural network classifier model for X_kbest and evaluate the results, print all the metrics


from sklearn.neural_network import MLPClassifier
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, classification_report, confusion_matrix

# Split the data into training and testing sets

mlp_gs = MLPClassifier(max_iter=10)
parameter_space = {
    'hidden_layer_sizes': [(10,),(20,),(30,)],
    'activation': ['tanh', 'relu'],
    'solver': ['sgd', 'adam'],
    'alpha': [0.0001, 0.05],
    'learning_rate': ['constant','adaptive'],
}
from sklearn.model_selection import GridSearchCV
clf = GridSearchCV(mlp_gs, parameter_space, n_jobs=-1, cv=5)
#clf.fit(X, y)

# Initialize the MLP classifier
#mlp = MLPClassifier(hidden_layer_sizes=(100,), max_iter=1000, alpha=0.0001,
#                     solver='adam', verbose=10,  random_state=21,tol=0.00000001)

# Train the model
clf.fit(X_train, y_train)
print('Best parameters found:\n', clf.best_params_)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-49-34060227736d> in <cell line: 27>()
#      25
#      26 # Train the model
# ---> 27 clf.fit(X_train, y_train)
#      28 print('Best parameters found:\n', clf.best_params_)
#
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py in wrapper(estimator, *args, **kwargs)
#    1150                 )
#    1151             ):
# -> 1152                 return fit_method(estimator, *args, **kwargs)
#    1153
#    1154         return wrapper
#
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_search.py in fit(self, X, y, groups, **fit_params)
#     896                 return results
#     897
# --> 898             self._run_search(evaluate_candidates)
#     899
#     900             # multimetric is determined here because in the case of a callable
#
# ...

# %%
# prompt: create a neural network classifier for X_sf and y

# Initialize the MLP classifier
mlp = MLPClassifier(hidden_layer_sizes=(100,), max_iter=1000, alpha=0.0001,
                     solver='adam', verbose=10,  random_state=251,tol=0.00000001)

# Train the model
mlp.fit(X_train, y_train)

# Make predictions on the test set
y_pred = mlp.predict(X_test)

# Evaluate the model
accuracy = accuracy_score(y_test, y_pred)
precision = precision_score(y_test, y_pred, average='weighted')
recall = recall_score(y_test, y_pred, average='weighted')
f1 = f1_score(y_test, y_pred, average='weighted')

print("Accuracy:", accuracy)
print("Precision:", precision)
print("Recall:", recall)
print("F1-score:", f1)

print(classification_report(y_test, y_pred))
print(confusion_matrix(y_test, y_pred))
# Out:
# Iteration 1, loss = 1.06955592
# Iteration 2, loss = 1.06829527
# Iteration 3, loss = 1.06823290
# Iteration 4, loss = 1.06814342
# Iteration 5, loss = 1.06794770
# Iteration 6, loss = 1.06783894
# Iteration 7, loss = 1.06779495
# Iteration 8, loss = 1.06770405
# Iteration 9, loss = 1.06758326
# Iteration 10, loss = 1.06752230
# Iteration 11, loss = 1.06740888
# Iteration 12, loss = 1.06736570
# Iteration 13, loss = 1.06744796
# Iteration 14, loss = 1.06725461
# Iteration 15, loss = 1.06723931
# Iteration 16, loss = 1.06724415
# Iteration 17, loss = 1.06711494
# Iteration 18, loss = 1.06712232
# Iteration 19, loss = 1.06707107
# Iteration 20, loss = 1.06708055
# Iteration 21, loss = 1.06702146
# Iteration 22, loss = 1.06699300
# Iteration 23, loss = 1.06700867
# Iteration 24, loss = 1.06698679
# Iteration 25, loss = 1.06706558
# Iteration 26, loss = 1.06694537
# Iteration 27, loss = 1.06697653
# Iteration 28, loss = 1.06695158
# Iteration 29, loss = 1.06696454
# ...

# %%
# Make predictions on the test set
y_pred = mlp.predict(X_test)

# Evaluate the model
accuracy = accuracy_score(y_test, y_pred)
precision = precision_score(y_test, y_pred, average='weighted')
recall = recall_score(y_test, y_pred, average='weighted')
f1 = f1_score(y_test, y_pred, average='weighted')

print("Accuracy:", accuracy)
print("Precision:", precision)
print("Recall:", recall)
print("F1-score:", f1)

# Print classification report
print("\nClassification Report:\n", classification_report(y_test, y_pred))
# Out:
# Accuracy: 0.4257578484560204
# Precision: 0.34282419919762935
# Recall: 0.4257578484560204
# F1-score: 0.2804880216010934
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00      9459
#            1       0.42      0.97      0.59     16459
#            2       0.49      0.05      0.09     12975
#
#     accuracy                           0.43     38893
#    macro avg       0.30      0.34      0.23     38893
# weighted avg       0.34      0.43      0.28     38893
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1471: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# ...

# %%
# prompt: display the confusion matrix in a pretty way and name the classes from selected_features

import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import confusion_matrix

# Assuming y_test and y_pred are defined from your previous code

cm = confusion_matrix(y_test, y_pred)

# Get class names from your selected features (replace with your actual class names)
class_names = list(['V','M','F'])

plt.figure(figsize=(10, 7))
sns.heatmap(cm, annot=True, fmt='d', cmap='Greens', xticklabels=class_names, yticklabels=class_names)
plt.title('Confusion Matrix')
plt.ylabel('Actual Label')
plt.xlabel('Predicted Label')
plt.show()

# %%
# prompt: apply voting algorithm for a series of classifiers to X_kbest and y

from sklearn.ensemble import VotingClassifier
from sklearn.linear_model import Ridge
from sklearn.tree import DecisionTreeClassifier
from sklearn.svm import SVC

# Create a list of classifiers
classifiers = [
    #('r', Ridge()),
    ('dt', DecisionTreeClassifier()),
    ('svc', SVC(probability=True))  # probability=True is needed for soft voting
]

# Create a voting classifier
voting_clf = VotingClassifier(estimators=classifiers, voting='soft')

# Fit the voting classifier to the data
voting_clf.fit(X_train, y_train)

# Make predictions on the test set
y_pred = voting_clf.predict(X_test)

# Evaluate the model
accuracy = accuracy_score(y_test, y_pred)
precision = precision_score(y_test, y_pred, average='weighted')
recall = recall_score(y_test, y_pred, average='weighted')
f1 = f1_score(y_test, y_pred, average='weighted')

print("Accuracy:", accuracy)
print("Precision:", precision)
print("Recall:", recall)
print("F1-score:", f1)

# Print classification report
print("\nClassification Report:\n", classification_report(y_test, y_pred))

# Assuming y_test and y_pred are defined from your previous code

cm = confusion_matrix(y_test, y_pred)

# Get class names from your selected features (replace with your actual class names)
class_names = list(before_labeling['LAW_CAT_CD'].unique())

plt.figure(figsize=(10, 7))
sns.heatmap(cm, annot=True, fmt='d', cmap='Greens', xticklabels=class_names, yticklabels=class_names)
plt.title('Confusion Matrix')
plt.ylabel('Actual Label')
plt.xlabel('Predicted Label')
plt.show()
