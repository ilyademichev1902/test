# %% [markdown]
# <a href="https://colab.research.google.com/github/ilyademichev1902/test/blob/main/NYC_sex_versus_type_of_crime.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# prompt: attach google drive folder to read the dataset

from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# prompt: read csv file "cny.csv"

import pandas as pd

df = pd.read_csv('/content/drive/My Drive/datascience/NYPD_Complaint_Data_Current__Year_To_Date_better.csv')
df.head()
# Out:
#   CMPLNT_NUM  ADDR_PCT_CD        BORO_NM CMPLNT_FR_DT CMPLNT_FR_TM  \
# 0  280510523           14      MANHATTAN   01/11/2024     04:00:00
# 1  286736978          122  STATEN ISLAND   01/01/2015     13:00:00
# 2  289019347            1      MANHATTAN   06/20/2024     16:12:00
# 3  283688417          121  STATEN ISLAND   03/11/2024     10:00:00
# 4  280934552          122  STATEN ISLAND   11/14/2023     12:00:00
#
#   CMPLNT_TO_DT CMPLNT_TO_TM CRM_ATPT_CPTD_CD HADEVELOPT  HOUSING_PSA  ...  \
# 0          NaN       (null)        COMPLETED     (null)          NaN  ...
# 1   01/01/2015     15:00:00        COMPLETED     (null)          NaN  ...
# 2   06/20/2024     16:13:00        COMPLETED     (null)          NaN  ...
# 3   03/13/2024     13:20:00        COMPLETED     (null)          NaN  ...
# 4   11/17/2023     12:00:00        COMPLETED     (null)          NaN  ...
#
#    TRANSIT_DISTRICT VIC_AGE_GROUP  VIC_RACE VIC_SEX X_COORD_CD Y_COORD_CD  \
# 0               NaN         18-24     BLACK       F   985764.0   213806.0
# 1               NaN         25-44   UNKNOWN       F   954827.0   148519.0
# 2               2.0         25-44     BLACK       F   982466.0   197787.0
# 3               NaN         25-44     BLACK       F   938414.0   170500.0
# 4               NaN           65+     WHITE       M   941085.0   135276.0
#
#     Latitude  Longitude                                  Lat_Lon  \
# 0  40.753533 -73.994537    (40.7535327012632, -73.9945368920152)
# 1  40.574286 -74.105914    (40.5742856881925, -74.1059144051212)
# 2  40.709556 -74.006435  (40.70955616028041, -74.00643483276845)
# 3  40.634542 -74.165142                  (40.634542, -74.165142)
# 4  40.537874 -74.155293                  (40.537874, -74.155293)
#
#                        New Georeferenced Column
# 0    POINT (-73.9945368920152 40.7535327012632)
# 1    POINT (-74.1059144051212 40.5742856881925)
# 2  POINT (-74.00643483276845 40.70955616028041)
# 3                  POINT (-74.165142 40.634542)
# 4                  POINT (-74.155293 40.537874)
#
# [5 rows x 36 columns]

# %%
# prompt: print number of rows in df dataframe

print("Rows total:",len(df))
# Out:
# Rows total: 282069

# %%
# prompt: replace values of (null) by NaN in df dataset
print("Before replacing\nAmount of missed values:\n")
print(df.isna().sum())
#df.head()
# Out:
# Before replacing
# Amount of missed values:
#
# CMPLNT_NUM                       0
# ADDR_PCT_CD                      0
# BORO_NM                          0
# CMPLNT_FR_DT                     0
# CMPLNT_FR_TM                     0
# CMPLNT_TO_DT                 14883
# CMPLNT_TO_TM                     0
# CRM_ATPT_CPTD_CD                 0
# HADEVELOPT                       0
# HOUSING_PSA                 264419
# JURISDICTION_CODE                0
# JURIS_DESC                       0
# KY_CD                            0
# LAW_CAT_CD                       0
# LOC_OF_OCCUR_DESC                0
# OFNS_DESC                        0
# PARKS_NM                         0
# PATROL_BORO                      0
# PD_CD                          172
# PD_DESC                          0
# PREM_TYP_DESC                    0
# RPT_DT                           0
# STATION_NAME                     0
# SUSP_AGE_GROUP                   0
# SUSP_RACE                        0
# SUSP_SEX                         0
# TRANSIT_DISTRICT            269621
# VIC_AGE_GROUP                    0
# VIC_RACE                         0
# VIC_SEX                          0
# X_COORD_CD                       4
# Y_COORD_CD                       4
# Latitude                         4
# Longitude                        4
# Lat_Lon                          4
# New Georeferenced Column         4
# dtype: int64

# %%
#replace text nulls

#df.head()

# %%
#replace text NaNs
import numpy as np

filler = pd.NA

df.replace('NaN', filler , inplace=True)
df.replace(np.nan, filler, inplace=True)
df.replace('(null)', filler, inplace=True)


print("After text null and Nan replacing into pandas.NaN:")

print(df.isna().sum())
# Out:
# After text null and Nan replacing into pandas.NaN:
# CMPLNT_NUM                       0
# ADDR_PCT_CD                      0
# BORO_NM                        150
# CMPLNT_FR_DT                     0
# CMPLNT_FR_TM                     0
# CMPLNT_TO_DT                 14883
# CMPLNT_TO_TM                 14671
# CRM_ATPT_CPTD_CD                 0
# HADEVELOPT                  281219
# HOUSING_PSA                 264419
# JURISDICTION_CODE                0
# JURIS_DESC                       0
# KY_CD                            0
# LAW_CAT_CD                       0
# LOC_OF_OCCUR_DESC            60868
# OFNS_DESC                        5
# PARKS_NM                    280551
# PATROL_BORO                      0
# PD_CD                          172
# PD_DESC                        172
# PREM_TYP_DESC                12573
# RPT_DT                           0
# STATION_NAME                269621
# SUSP_AGE_GROUP               31808
# SUSP_RACE                    31808
# SUSP_SEX                     31808
# TRANSIT_DISTRICT            269621
# VIC_AGE_GROUP                    0
# VIC_RACE                        14
# VIC_SEX                          0
# X_COORD_CD                       4
# Y_COORD_CD                       4
# Latitude                         4
# Longitude                        4
# Lat_Lon                          4
# New Georeferenced Column         4
# dtype: int64

# %%
# prompt: list columns by index
threshold = 90
threshold_number = int(len(df) * threshold/100)
print("\n".join([str(num)+":"+str(col)+" missing" if int(col)>threshold_number else str(num)+":"+">"+str(threshold)+"% present" for num,col in enumerate(df.isna().sum())]))
# Out:
# 0:>90% present
# 1:>90% present
# 2:>90% present
# 3:>90% present
# 4:>90% present
# 5:>90% present
# 6:>90% present
# 7:>90% present
# 8:281219 missing
# 9:264419 missing
# 10:>90% present
# 11:>90% present
# 12:>90% present
# 13:>90% present
# 14:>90% present
# 15:>90% present
# 16:280551 missing
# 17:>90% present
# 18:>90% present
# 19:>90% present
# 20:>90% present
# 21:>90% present
# 22:269621 missing
# 23:>90% present
# 24:>90% present
# 25:>90% present
# 26:269621 missing
# 27:>90% present
# 28:>90% present
# 29:>90% present
# 30:>90% present
# 31:>90% present
# 32:>90% present
# 33:>90% present
# 34:>90% present
# 35:>90% present

# %%
# prompt: eliminate from df dataframe columns 35 and 36

#df = df.drop(df.columns[[8,9,16, 41]], axis=1)
#df = df.drop(df.columns[list(range(20,38))], axis=1)
df = df.drop(df.columns[[8,9,16,22,26]], axis=1)

# %%
# prompt: drop last column

#df = df.iloc[:, :-1]

# %%
# prompt: eliminate TRANSIT_DISTRICT column

#df = df.drop('TRANSIT_DISTRICT', axis=1)
#df = df.drop('STATION_NAME', axis=1)
#print("After dropping missed and 95% missed columns:",df.isnull().sum())

# %%
#df.dropna(inplace=True)
#df = df.drop('Unnamed: 40', axis=1)
print("After dropping columns with less than {}% data present ,still missing".format(threshold))
print(df.isna().sum())
# Out:
# After dropping columns with less than 90% data present ,still missing
# CMPLNT_NUM                      0
# ADDR_PCT_CD                     0
# BORO_NM                       150
# CMPLNT_FR_DT                    0
# CMPLNT_FR_TM                    0
# CMPLNT_TO_DT                14883
# CMPLNT_TO_TM                14671
# CRM_ATPT_CPTD_CD                0
# JURISDICTION_CODE               0
# JURIS_DESC                      0
# KY_CD                           0
# LAW_CAT_CD                      0
# LOC_OF_OCCUR_DESC           60868
# OFNS_DESC                       5
# PATROL_BORO                     0
# PD_CD                         172
# PD_DESC                       172
# PREM_TYP_DESC               12573
# RPT_DT                          0
# SUSP_AGE_GROUP              31808
# SUSP_RACE                   31808
# SUSP_SEX                    31808
# VIC_AGE_GROUP                   0
# VIC_RACE                       14
# VIC_SEX                         0
# X_COORD_CD                      4
# Y_COORD_CD                      4
# Latitude                        4
# Longitude                       4
# Lat_Lon                         4
# New Georeferenced Column        4
# dtype: int64

# %%
df.fillna('NOT SPECIFIED', inplace=True)
print(df.isna().sum())
# Out:
# CMPLNT_NUM                  0
# ADDR_PCT_CD                 0
# BORO_NM                     0
# CMPLNT_FR_DT                0
# CMPLNT_FR_TM                0
# CMPLNT_TO_DT                0
# CMPLNT_TO_TM                0
# CRM_ATPT_CPTD_CD            0
# JURISDICTION_CODE           0
# JURIS_DESC                  0
# KY_CD                       0
# LAW_CAT_CD                  0
# LOC_OF_OCCUR_DESC           0
# OFNS_DESC                   0
# PATROL_BORO                 0
# PD_CD                       0
# PD_DESC                     0
# PREM_TYP_DESC               0
# RPT_DT                      0
# SUSP_AGE_GROUP              0
# SUSP_RACE                   0
# SUSP_SEX                    0
# VIC_AGE_GROUP               0
# VIC_RACE                    0
# VIC_SEX                     0
# X_COORD_CD                  0
# Y_COORD_CD                  0
# Latitude                    0
# Longitude                   0
# Lat_Lon                     0
# New Georeferenced Column    0
# dtype: int64

# %%
# prompt: replace numpy NaN with pandas NaN , drop rows that contain pandas NaN

# Drop rows with pandas NaN
before_dropna = df.copy(deep=True)
df.dropna(inplace=True)

# %%
print("Data rows left")
print(len(df))
# Out:
# Data rows left
# 282069

# %%
#print amount of unique values for each column
print("Unnique values for each column\n")
print(df.nunique())
# Out:
# Unnique values for each column
#
# CMPLNT_NUM                  282069
# ADDR_PCT_CD                     77
# BORO_NM                          6
# CMPLNT_FR_DT                  1516
# CMPLNT_FR_TM                  1440
# CMPLNT_TO_DT                  1030
# CMPLNT_TO_TM                  1441
# CRM_ATPT_CPTD_CD                 2
# JURISDICTION_CODE               20
# JURIS_DESC                      20
# KY_CD                           66
# LAW_CAT_CD                       3
# LOC_OF_OCCUR_DESC                6
# OFNS_DESC                       63
# PATROL_BORO                      8
# PD_CD                          367
# PD_DESC                        357
# PREM_TYP_DESC                   83
# RPT_DT                         182
# SUSP_AGE_GROUP                  19
# SUSP_RACE                        8
# SUSP_SEX                         4
# VIC_AGE_GROUP                   24
# VIC_RACE                         8
# VIC_SEX                          5
# X_COORD_CD                   41317
# Y_COORD_CD                   43711
# Latitude                     53529
# Longitude                    53736
# Lat_Lon                      56160
# New Georeferenced Column     56160
# dtype: int64

# %%
# prompt: drop last 6 columns

df = df.iloc[:, :-6]

# %%
# prompt: drop columns from ['JURISDICTION_CODE', 'PD_CD','CMPLNT_NUM','KY_CD'] if exist
# display the head

# Drop columns if they exist
for col in ['JURISDICTION_CODE', 'PD_CD','CMPLNT_NUM','KY_CD','ADDR_PCT_CD','PATROL_BORO','JURIS_DESC','RPT_DT']:
  if col in df.columns:
    df = df.drop(col, axis=1)

# %%
# Display the head

df.head()
# Out:
#          BORO_NM CMPLNT_FR_DT CMPLNT_FR_TM   CMPLNT_TO_DT   CMPLNT_TO_TM  \
# 0      MANHATTAN   01/11/2024     04:00:00  NOT SPECIFIED  NOT SPECIFIED
# 1  STATEN ISLAND   01/01/2015     13:00:00     01/01/2015       15:00:00
# 2      MANHATTAN   06/20/2024     16:12:00     06/20/2024       16:13:00
# 3  STATEN ISLAND   03/11/2024     10:00:00     03/13/2024       13:20:00
# 4  STATEN ISLAND   11/14/2023     12:00:00     11/17/2023       12:00:00
#
#   CRM_ATPT_CPTD_CD   LAW_CAT_CD LOC_OF_OCCUR_DESC      OFNS_DESC  \
# 0        COMPLETED       FELONY            INSIDE           RAPE
# 1        COMPLETED  MISDEMEANOR            INSIDE     SEX CRIMES
# 2        COMPLETED    VIOLATION     NOT SPECIFIED  HARRASSMENT 2
# 3        COMPLETED  MISDEMEANOR          FRONT OF  PETIT LARCENY
# 4        COMPLETED       FELONY            INSIDE  GRAND LARCENY
#
#                                        PD_DESC         PREM_TYP_DESC  \
# 0                                       RAPE 1           HOTEL/MOTEL
# 1                             SEXUAL ABUSE 3,2       RESIDENCE-HOUSE
# 2                   HARASSMENT,SUBD 1,CIVILIAN  TRANSIT - NYC SUBWAY
# 3               LARCENY,PETIT FROM OPEN AREAS,       MAILBOX OUTSIDE
# 4  LARCENY,GRAND BY ACQUIRING LOST CREDIT CARD       RESIDENCE-HOUSE
#
#   SUSP_AGE_GROUP      SUSP_RACE       SUSP_SEX VIC_AGE_GROUP VIC_RACE VIC_SEX
# 0          18-24          BLACK              U         18-24    BLACK       F
# 1          25-44        UNKNOWN              M         25-44  UNKNOWN       F
# 2          45-64          BLACK              M         25-44    BLACK       F
# 3  NOT SPECIFIED  NOT SPECIFIED  NOT SPECIFIED         25-44    BLACK       F
# 4  NOT SPECIFIED  NOT SPECIFIED  NOT SPECIFIED           65+    WHITE       M

# %%
# prompt: number of unique values for each column , display unique values if amount is less than 5
categorical = {}
for col in df.columns:
  unique_vals = df[col].unique()
  num_unique = len(unique_vals)
  #print(f"Column '{col}': {num_unique} unique values")
  if num_unique <= 5:
    categorical[col] = unique_vals
    #print(f"{col}:15: {unique_vals}")

# %%
# prompt:  print a dictionary categorical in a  table , each column with increasing number of values

import pandas as pd

# Create a DataFrame from the dictionary
df_categorical = pd.DataFrame.from_dict(categorical, orient='index').transpose()

# Sort columns by the number of unique values
df_categorical = df_categorical.reindex(sorted(df_categorical.columns, key=lambda col: df_categorical[col].nunique()), axis=1)

# Display the DataFrame as a table
df_categorical
# Out:
#   CRM_ATPT_CPTD_CD   LAW_CAT_CD       SUSP_SEX VIC_SEX
# 0        COMPLETED       FELONY              U       F
# 1        ATTEMPTED  MISDEMEANOR              M       M
# 2             None    VIOLATION  NOT SPECIFIED       D
# 3             None         None              F       L
# 4             None         None           None       E

# %%
# prompt: drop features from df by names from list [CMPLNT_FR_DT ,	CMPLNT_FR_TM 	,CMPLNT_TO_DT 	,CMPLNT_TO_TM 	,CRM_ATPT_CPTD_CD 	]

features_to_drop = [  'CMPLNT_TO_DT', 'CMPLNT_TO_TM', 'CRM_ATPT_CPTD_CD']

for feature in features_to_drop:
  if feature in df.columns:
    df = df.drop(feature, axis=1)
#df.head()

# %%
# prompt: extract an hour from CMPLNT_FR_TM and put it inside the cell , drop CMPLNT_FR_TM

# Extract the hour from 'CMPLNT_FR_TM' and create a new column 'Hour'
df['Hour'] = pd.to_datetime(df['CMPLNT_FR_TM'], format='%H:%M:%S').dt.hour

# Drop the original 'CMPLNT_FR_TM' column
df = df.drop('CMPLNT_FR_TM', axis=1)

df.head()
# Out:
#          BORO_NM CMPLNT_FR_DT   LAW_CAT_CD LOC_OF_OCCUR_DESC      OFNS_DESC  \
# 0      MANHATTAN   01/11/2024       FELONY            INSIDE           RAPE
# 1  STATEN ISLAND   01/01/2015  MISDEMEANOR            INSIDE     SEX CRIMES
# 2      MANHATTAN   06/20/2024    VIOLATION     NOT SPECIFIED  HARRASSMENT 2
# 3  STATEN ISLAND   03/11/2024  MISDEMEANOR          FRONT OF  PETIT LARCENY
# 4  STATEN ISLAND   11/14/2023       FELONY            INSIDE  GRAND LARCENY
#
#                                        PD_DESC         PREM_TYP_DESC  \
# 0                                       RAPE 1           HOTEL/MOTEL
# 1                             SEXUAL ABUSE 3,2       RESIDENCE-HOUSE
# 2                   HARASSMENT,SUBD 1,CIVILIAN  TRANSIT - NYC SUBWAY
# 3               LARCENY,PETIT FROM OPEN AREAS,       MAILBOX OUTSIDE
# 4  LARCENY,GRAND BY ACQUIRING LOST CREDIT CARD       RESIDENCE-HOUSE
#
#   SUSP_AGE_GROUP      SUSP_RACE       SUSP_SEX VIC_AGE_GROUP VIC_RACE VIC_SEX  \
# 0          18-24          BLACK              U         18-24    BLACK       F
# 1          25-44        UNKNOWN              M         25-44  UNKNOWN       F
# 2          45-64          BLACK              M         25-44    BLACK       F
# 3  NOT SPECIFIED  NOT SPECIFIED  NOT SPECIFIED         25-44    BLACK       F
# 4  NOT SPECIFIED  NOT SPECIFIED  NOT SPECIFIED           65+    WHITE       M
#
#    Hour
# 0     4
# 1    13
# 2    16
# 3    10
# 4    12

# %%
# prompt: eliminate CMPLNT_FR_DT

if 'CMPLNT_FR_DT' in df.columns:
  df = df.drop('CMPLNT_FR_DT', axis=1)
df.head()
# Out:
#          BORO_NM   LAW_CAT_CD LOC_OF_OCCUR_DESC      OFNS_DESC  \
# 0      MANHATTAN       FELONY            INSIDE           RAPE
# 1  STATEN ISLAND  MISDEMEANOR            INSIDE     SEX CRIMES
# 2      MANHATTAN    VIOLATION     NOT SPECIFIED  HARRASSMENT 2
# 3  STATEN ISLAND  MISDEMEANOR          FRONT OF  PETIT LARCENY
# 4  STATEN ISLAND       FELONY            INSIDE  GRAND LARCENY
#
#                                        PD_DESC         PREM_TYP_DESC  \
# 0                                       RAPE 1           HOTEL/MOTEL
# 1                             SEXUAL ABUSE 3,2       RESIDENCE-HOUSE
# 2                   HARASSMENT,SUBD 1,CIVILIAN  TRANSIT - NYC SUBWAY
# 3               LARCENY,PETIT FROM OPEN AREAS,       MAILBOX OUTSIDE
# 4  LARCENY,GRAND BY ACQUIRING LOST CREDIT CARD       RESIDENCE-HOUSE
#
#   SUSP_AGE_GROUP      SUSP_RACE       SUSP_SEX VIC_AGE_GROUP VIC_RACE VIC_SEX  \
# 0          18-24          BLACK              U         18-24    BLACK       F
# 1          25-44        UNKNOWN              M         25-44  UNKNOWN       F
# 2          45-64          BLACK              M         25-44    BLACK       F
# 3  NOT SPECIFIED  NOT SPECIFIED  NOT SPECIFIED         25-44    BLACK       F
# 4  NOT SPECIFIED  NOT SPECIFIED  NOT SPECIFIED           65+    WHITE       M
#
#    Hour
# 0     4
# 1    13
# 2    16
# 3    10
# 4    12

# %%
# prompt: drop columns starting from SUSP

cols_to_drop = [col for col in df.columns if col.startswith('SUSP')]
df = df.drop(columns=cols_to_drop)
df.head()
# Out:
#          BORO_NM   LAW_CAT_CD LOC_OF_OCCUR_DESC      OFNS_DESC  \
# 0      MANHATTAN       FELONY            INSIDE           RAPE
# 1  STATEN ISLAND  MISDEMEANOR            INSIDE     SEX CRIMES
# 2      MANHATTAN    VIOLATION     NOT SPECIFIED  HARRASSMENT 2
# 3  STATEN ISLAND  MISDEMEANOR          FRONT OF  PETIT LARCENY
# 4  STATEN ISLAND       FELONY            INSIDE  GRAND LARCENY
#
#                                        PD_DESC         PREM_TYP_DESC  \
# 0                                       RAPE 1           HOTEL/MOTEL
# 1                             SEXUAL ABUSE 3,2       RESIDENCE-HOUSE
# 2                   HARASSMENT,SUBD 1,CIVILIAN  TRANSIT - NYC SUBWAY
# 3               LARCENY,PETIT FROM OPEN AREAS,       MAILBOX OUTSIDE
# 4  LARCENY,GRAND BY ACQUIRING LOST CREDIT CARD       RESIDENCE-HOUSE
#
#   VIC_AGE_GROUP VIC_RACE VIC_SEX  Hour
# 0         18-24    BLACK       F     4
# 1         25-44  UNKNOWN       F    13
# 2         25-44    BLACK       F    16
# 3         25-44    BLACK       F    10
# 4           65+    WHITE       M    12

# %%
before_labeling = df.copy(deep=True)

# %%
# prompt: based on CMPLNT_FR_DT feature eliminate rows that happened on weekends and holidays of NYC,US . CMPLNT_FR_DT is a text representation of a date

# from datetime import datetime
# import holidays

# us_holidays = holidays.US(years=[2023])  # Assuming your data is from 2023, adjust if needed

# def is_weekend_or_holiday(date_str):
#   try:
#     date = datetime.strptime(date_str, '%m/%d/%Y')
#     return date.weekday() >= 5 or date in us_holidays
#   except ValueError:
#     return False

# # Filter out rows where the date is a weekend or holiday
# df = df[~df['CMPLNT_FR_DT'].apply(is_weekend_or_holiday)]

# %%
# prompt: display unique values for each column ,include missing , create a dataframe for better comprehension with small variation of values,extract large variations of values into another separate dataframe . Show both dataframes transposed

# Create a dictionary to store unique values for each column, including missing values
unique_values_dict = {}
for col in df.columns:
  unique_values_dict[col] = df[col].unique()

# Create a DataFrame from the dictionary
df_unique_values = pd.DataFrame.from_dict(unique_values_dict, orient='index').transpose()

# Transpose the DataFrame for better readability
df_unique_values_transposed = df_unique_values.transpose()

# Display the transposed DataFrame
#print("Unique values for each column (including missing values):")
#print(df_unique_values_transposed)


# Create a dictionary to store unique values for each column, including missing values
small_variation_dict = {}
large_variation_dict = {}
for col in df.columns:
  unique_values = df[col].unique()
  num_unique = len(unique_values)
  if num_unique <= 25:
    small_variation_dict[col] = unique_values
  else:
    large_variation_dict[col] = unique_values


# Create DataFrames from the dictionaries
df_small_variation = pd.DataFrame.from_dict(small_variation_dict, orient='index').transpose()
df_large_variation = pd.DataFrame.from_dict(large_variation_dict, orient='index').transpose()


# Transpose the DataFrames for better readability
#df_small_variation_transposed = df_small_variation.transpose()
#df_large_variation_transposed = df_large_variation.transpose()

# Display the transposed DataFrames
print("\nSmall Variation Dataframe (Transposed):")
display(df_small_variation)
# Out:
# Small Variation Dataframe (Transposed):
#           BORO_NM   LAW_CAT_CD LOC_OF_OCCUR_DESC VIC_AGE_GROUP  \
# 0       MANHATTAN       FELONY            INSIDE         18-24
# 1   STATEN ISLAND  MISDEMEANOR     NOT SPECIFIED         25-44
# 2           BRONX    VIOLATION          FRONT OF           65+
# 3        BROOKLYN         None           OUTSIDE         45-64
# 4   NOT SPECIFIED         None           REAR OF       UNKNOWN
# 5          QUEENS         None       OPPOSITE OF           <18
# 6            None         None              None            -1
# 7            None         None              None          -973
# 8            None         None              None          -958
# 9            None         None              None           940
# 10           None         None              None           -28
# 11           None         None              None           966
# 12           None         None              None          -951
# 13           None         None              None          -965
# 14           None         None              None           953
# 15           None         None              None           928
# 16           None         None              None           960
# 17           None         None              None          -972
# 18           None         None              None           944
# 19           None         None              None          1023
# 20           None         None              None           934
# 21           None         None              None           957
# 22           None         None              None          -924
# 23           None         None              None           963
#
#                           VIC_RACE VIC_SEX Hour
# 0                            BLACK       F    4
# 1                          UNKNOWN       M   13
# 2                            WHITE       D   16
# 3                   WHITE HISPANIC       L   10
# 4         ASIAN / PACIFIC ISLANDER       E   12
# 5   AMERICAN INDIAN/ALASKAN NATIVE    None   14
# 6                   BLACK HISPANIC    None   19
# 7                    NOT SPECIFIED    None   22
# 8                             None    None   18
# 9                             None    None   17
# 10                            None    None    5
# 11                            None    None    6
# 12                            None    None   15
# 13                            None    None    8
# 14                            None    None   20
# 15                            None    None    0
# 16                            None    None   21
# 17                            None    None    2
# 18                            None    None   23
# 19                            None    None   11
# 20                            None    None    1
# 21                            None    None    9
# 22                            None    None    7
# 23                            None    None    3

# %%
print("\nLarge Variation Dataframe (Transposed):")
display(df_large_variation)
# Out:
# Large Variation Dataframe (Transposed):
#          OFNS_DESC                                      PD_DESC  \
# 0             RAPE                                       RAPE 1
# 1       SEX CRIMES                             SEXUAL ABUSE 3,2
# 2    HARRASSMENT 2                   HARASSMENT,SUBD 1,CIVILIAN
# 3    PETIT LARCENY               LARCENY,PETIT FROM OPEN AREAS,
# 4    GRAND LARCENY  LARCENY,GRAND BY ACQUIRING LOST CREDIT CARD
# ..             ...                                          ...
# 352           None               LARCENY,PETIT FROM PARKING MET
# 353           None                                   SEX CRIMES
# 354           None                                 DOG STEALING
# 355           None                        LARCENY,PETIT OF BOAT
# 356           None                             PLACE FALSE BOMB
#
#             PREM_TYP_DESC
# 0             HOTEL/MOTEL
# 1         RESIDENCE-HOUSE
# 2    TRANSIT - NYC SUBWAY
# 3         MAILBOX OUTSIDE
# 4           NOT SPECIFIED
# ..                    ...
# 352                  None
# 353                  None
# 354                  None
# 355                  None
# 356                  None
#
# [357 rows x 3 columns]

# %%
# prompt: check for empty cells

# Check for empty cells in the DataFrame
empty_cells = df.isnull().sum()

# Print the number of empty cells for each column
print("Empty cells in each column:")
print(empty_cells)

# Check if there are any empty cells in the entire DataFrame
if df.isnull().values.any():
  print("\nThe DataFrame contains empty cells.")
else:
  print("\nThe DataFrame does not contain any empty cells.")
# Out:
# Empty cells in each column:
# BORO_NM              0
# LAW_CAT_CD           0
# LOC_OF_OCCUR_DESC    0
# OFNS_DESC            0
# PD_DESC              0
# PREM_TYP_DESC        0
# VIC_AGE_GROUP        0
# VIC_RACE             0
# VIC_SEX              0
# Hour                 0
# dtype: int64
#
# The DataFrame does not contain any empty cells.

# %%
# prompt: eliminate [ OFNS_DESC , PD_DES]

columns_to_eliminate = ['LOC_OF_OCCUR_DESC' ]#, 'PD_DESC']

for column in columns_to_eliminate:
  if column in df.columns:
    df = df.drop(column, axis=1)

df.head()
# Out:
#          BORO_NM   LAW_CAT_CD      OFNS_DESC  \
# 0      MANHATTAN       FELONY           RAPE
# 1  STATEN ISLAND  MISDEMEANOR     SEX CRIMES
# 2      MANHATTAN    VIOLATION  HARRASSMENT 2
# 3  STATEN ISLAND  MISDEMEANOR  PETIT LARCENY
# 4  STATEN ISLAND       FELONY  GRAND LARCENY
#
#                                        PD_DESC         PREM_TYP_DESC  \
# 0                                       RAPE 1           HOTEL/MOTEL
# 1                             SEXUAL ABUSE 3,2       RESIDENCE-HOUSE
# 2                   HARASSMENT,SUBD 1,CIVILIAN  TRANSIT - NYC SUBWAY
# 3               LARCENY,PETIT FROM OPEN AREAS,       MAILBOX OUTSIDE
# 4  LARCENY,GRAND BY ACQUIRING LOST CREDIT CARD       RESIDENCE-HOUSE
#
#   VIC_AGE_GROUP VIC_RACE VIC_SEX  Hour
# 0         18-24    BLACK       F     4
# 1         25-44  UNKNOWN       F    13
# 2         25-44    BLACK       F    16
# 3         25-44    BLACK       F    10
# 4           65+    WHITE       M    12

# %%
# prompt: show unique values count for each column

for column in df.columns:
  unique_count = df[column].nunique()
  print(f"{column}: {unique_count} ")
# Out:
# BORO_NM: 6
# LAW_CAT_CD: 3
# OFNS_DESC: 63
# PD_DESC: 357
# PREM_TYP_DESC: 83
# VIC_AGE_GROUP: 24
# VIC_RACE: 8
# VIC_SEX: 5
# Hour: 24

# %%
# prompt: print unique values for SUSP_SEX

print(df['VIC_SEX'].unique())
# Out:
# ['F' 'M' 'D' 'L' 'E']

# %%
#prompt: eliminate PREM_TYP_DESC

if 'PREM_TYP_DESC' in df.columns:
  df = df.drop('PREM_TYP_DESC', axis=1)

df.head()
# Out:
#          BORO_NM   LAW_CAT_CD      OFNS_DESC  \
# 0      MANHATTAN       FELONY           RAPE
# 1  STATEN ISLAND  MISDEMEANOR     SEX CRIMES
# 2      MANHATTAN    VIOLATION  HARRASSMENT 2
# 3  STATEN ISLAND  MISDEMEANOR  PETIT LARCENY
# 4  STATEN ISLAND       FELONY  GRAND LARCENY
#
#                                        PD_DESC VIC_AGE_GROUP VIC_RACE VIC_SEX  \
# 0                                       RAPE 1         18-24    BLACK       F
# 1                             SEXUAL ABUSE 3,2         25-44  UNKNOWN       F
# 2                   HARASSMENT,SUBD 1,CIVILIAN         25-44    BLACK       F
# 3               LARCENY,PETIT FROM OPEN AREAS,         25-44    BLACK       F
# 4  LARCENY,GRAND BY ACQUIRING LOST CREDIT CARD           65+    WHITE       M
#
#    Hour
# 0     4
# 1    13
# 2    16
# 3    10
# 4    12

# %%
# prompt: show unique values for each column as a dataframe, show all the rows

# Create a dictionary to store unique values for each column
unique_values_dict = {}
for col in df.columns:
  unique_values_dict[col] = df[col].unique()

# Create a DataFrame from the dictionary
df_unique_values = pd.DataFrame.from_dict(unique_values_dict, orient='index').transpose()

# Display the DataFrame with all rows
pd.set_option('display.max_rows', None)
display(df_unique_values)
pd.reset_option('display.max_rows')
# Out:
#            BORO_NM   LAW_CAT_CD                             OFNS_DESC  \
# 0        MANHATTAN       FELONY                                  RAPE
# 1    STATEN ISLAND  MISDEMEANOR                            SEX CRIMES
# 2            BRONX    VIOLATION                         HARRASSMENT 2
# 3         BROOKLYN         None                         PETIT LARCENY
# 4    NOT SPECIFIED         None                         GRAND LARCENY
# 5           QUEENS         None       MURDER & NON-NEGL. MANSLAUGHTER
# 6             None         None        CRIMINAL MISCHIEF & RELATED OF
# 7             None         None        GRAND LARCENY OF MOTOR VEHICLE
# 8             None         None         OFF. AGNST PUB ORD SENSBLTY &
# 9             None         None              VEHICLE AND TRAFFIC LAWS
# 10            None         None                     CRIMINAL TRESPASS
# 11            None         None                        FELONY ASSAULT
# 12            None         None                               ROBBERY
# 13            None         None             CANNABIS RELATED OFFENSES
# 14            None         None          NYS LAWS-UNCLASSIFIED FELONY
# 15            None         None              OFFENSES INVOLVING FRAUD
# 16            None         None        INTOXICATED & IMPAIRED DRIVING
# 17            None         None                              GAMBLING
# 18            None         None          ASSAULT 3 & RELATED OFFENSES
# 19            None         None                    DISORDERLY CONDUCT
# 20            None         None        OFFENSES AGAINST PUBLIC ADMINI
# 21            None         None                              BURGLARY
# 22            None         None                       DANGEROUS DRUGS
# 23            None         None         POSSESSION OF STOLEN PROPERTY
# 24            None         None        OFFENSES AGAINST PUBLIC SAFETY
# 25            None         None                                FRAUDS
# 26            None         None                           THEFT-FRAUD
# 27            None         None               MISCELLANEOUS PENAL LAW
# 28            None         None         UNAUTHORIZED USE OF A VEHICLE
# 29            None         None                                 ARSON
# 30            None         None           OFFENSES AGAINST THE PERSON
# 31            None         None                     DANGEROUS WEAPONS
# 32            None         None                               FORGERY
# 33            None         None  AGRICULTURE & MRKTS LAW-UNCLASSIFIED
# 34            None         None                      OTHER STATE LAWS
# 35            None         None                   ADMINISTRATIVE CODE
# 36            None         None        OTHER STATE LAWS (NON PENAL LA
# 37            None         None         KIDNAPPING & RELATED OFFENSES
# 38            None         None                  FRAUDULENT ACCOSTING
# 39            None         None        DISRUPTION OF A RELIGIOUS SERV
# 40            None         None          OFFENSES RELATED TO CHILDREN
# 41            None         None       PROSTITUTION & RELATED OFFENSES
# 42            None         None                              JOSTLING
# 43            None         None                       BURGLAR'S TOOLS
# 44            None         None         CHILD ABANDONMENT/NON SUPPORT
# 45            None         None        PETIT LARCENY OF MOTOR VEHICLE
# 46            None         None                 ANTICIPATORY OFFENSES
# 47            None         None                  ENDAN WELFARE INCOMP
# 48            None         None                              ESCAPE 3
# 49            None         None        ALCOHOLIC BEVERAGE CONTROL LAW
# 50            None         None                     THEFT OF SERVICES
# 51            None         None        OTHER OFFENSES RELATED TO THEF
# 52            None         None        UNLAWFUL POSS. WEAP. ON SCHOOL
# 53            None         None       NYS LAWS-UNCLASSIFIED VIOLATION
# 54            None         None              OTHER TRAFFIC INFRACTION
# 55            None         None          INTOXICATED/IMPAIRED DRIVING
# 56            None         None                       FORTUNE TELLING
# 57            None         None                         NOT SPECIFIED
# 58            None         None        HOMICIDE-NEGLIGENT,UNCLASSIFIE
# 59            None         None                     FELONY SEX CRIMES
# 60            None         None                            KIDNAPPING
# 61            None         None        LOITERING/GAMBLING (CARDS, DIC
# 62            None         None                             LOITERING
# 63            None         None                                  None
# 64            None         None                                  None
# 65            None         None                                  None
# 66            None         None                                  None
# 67            None         None                                  None
# 68            None         None                                  None
# 69            None         None                                  None
# 70            None         None                                  None
# 71            None         None                                  None
# 72            None         None                                  None
# 73            None         None                                  None
# 74            None         None                                  None
# 75            None         None                                  None
# 76            None         None                                  None
# 77            None         None                                  None
# 78            None         None                                  None
# 79            None         None                                  None
# 80            None         None                                  None
# 81            None         None                                  None
# 82            None         None                                  None
# 83            None         None                                  None
# 84            None         None                                  None
# 85            None         None                                  None
# 86            None         None                                  None
# 87            None         None                                  None
# 88            None         None                                  None
# 89            None         None                                  None
# 90            None         None                                  None
# 91            None         None                                  None
# 92            None         None                                  None
# 93            None         None                                  None
# 94            None         None                                  None
# 95            None         None                                  None
# 96            None         None                                  None
# 97            None         None                                  None
# 98            None         None                                  None
# 99            None         None                                  None
# 100           None         None                                  None
# 101           None         None                                  None
# 102           None         None                                  None
# 103           None         None                                  None
# 104           None         None                                  None
# 105           None         None                                  None
# 106           None         None                                  None
# 107           None         None                                  None
# 108           None         None                                  None
# 109           None         None                                  None
# 110           None         None                                  None
# 111           None         None                                  None
# 112           None         None                                  None
# 113           None         None                                  None
# 114           None         None                                  None
ARCENY,GRAND BY ACQUIRING LOST CREDIT CARD       UNKNOWN
# 5                                        NOT SPECIFIED           <18
# 6                       MISCHIEF, CRIMINAL 3 & 2, OF M            -1
# 7    LARCENY,PETIT FROM BUILDING,UNATTENDED, PACKAG...          -973
# 8                                LARCENY,GRAND OF AUTO          -958
# 9                              AGGRAVATED HARASSMENT 2           940
# 10                      LEAVING SCENE-ACCIDENT-PERSONA           -28
# 11                                TRESPASS 3, CRIMINAL           966
# 12                                   STRANGULATION 1ST          -951
# 13                      LARCENY,PETIT FROM STORE-SHOPL          -965
# 14                             LARCENY,PETIT FROM AUTO           953
# 15                      ROBBERY,OPEN AREA UNCLASSIFIED           928
# 16   LARCENY,GRAND BY BANK ACCT COMPROMISE-ATM TRAN...           960
# 17                              CANNABIS POSSESSION, 3          -972
# 18                            ASSAULT 2,1,UNCLASSIFIED           944
# 19                      NY STATE LAWS,UNCLASSIFIED FEL          1023
# 20   LARCENY,PETIT FROM BUILDING,UNATTENDED, PACKAG...           934
# 21                                  FORGERY,ETC.-MISD.           957
# 22                         INTOXICATED DRIVING,ALCOHOL          -924
# 23                      MISCHIEF,CRIMINAL,    UNCL 2ND           963
# 24                               IMPAIRED DRIVING,DRUG          None
# 25                      TRAFFIC,UNCLASSIFIED MISDEMEAN          None
# 26                      GAMBLING 2,PROMOTING,UNCLASSIF          None
# 27                               MENACING,UNCLASSIFIED          None
# 28                      MISCHIEF, CRIMINAL 4, OF MOTOR          None
# 29                                  DISORDERLY CONDUCT          None
# 30                      LARCENY,PETIT BY CREDIT CARD U          None
# 31                      VIOLATION OF ORDER OF PROTECTI          None
# 32                                BURGLARY,TRUCK NIGHT          None
# 33                      CONTROLLED SUBSTANCE, POSSESSI          None
# 34                                 OBSTR BREATH/CIRCUL          None
# 35                      STOLEN PROPERTY 2,1,POSSESSION          None
# 36                      PETIT LARCENY-CHECK FROM MAILB          None
# 37                      LARCENY,GRAND BY ACQUIRING LOS          None
# 38                      PUBLIC SAFETY,UNCLASSIFIED MIS          None
# 39                      FRAUD,UNCLASSIFIED-MISDEMEANOR          None
# 40                         CONTROLLED SUBSTANCE,SALE 3          None
# 41                            LARCENY,PETIT OF BICYCLE          None
# 42                           FRAUD,UNCLASSIFIED-FELONY          None
# 43                       MENACING 1ST DEGREE (VICT NOT          None
# 44                      LARCENY,GRAND FROM PERSON,UNCL          None
# 45                          UNAUTHORIZED USE VEHICLE 3          None
# 46   LARCENY,GRAND BY FALSE PROMISE-NOT IN PERSON C...          None
# 47                                         ARSON 2,3,4          None
# 48                                    RESISTING ARREST          None
# 49           LARCENY,GRAND FROM OPEN AREAS, UNATTENDED          None
# 50                       CONTROLLED SUBSTANCE,POSSESS.          None
# 51   LARCENY,GRAND BY BANK ACCT COMPROMISE-UNCLASSI...          None
# 52                                TRESPASS 2, CRIMINAL          None
# 53                             IMPRISONMENT 2,UNLAWFUL          None
# 54                      LARCENY,PETIT BY FALSE PROMISE          None
# 55                                  CRIMINAL MIS 2 & 3          None
# 56                                        SEXUAL ABUSE          None
# 57   LARCENY,GRAND FROM BUILDING (NON-RESIDENCE) UN...          None
# 58                            WEAPONS, POSSESSION, ETC          None
# 59                      LARCENY,GRAND FROM STORE-SHOPL          None
# 60                      PUBLIC ADMINISTATION,UNCLASS M          None
# 61                      LARCENY,PETIT OF LICENSE PLATE          None
# 62                      MATERIAL              OFFENSIV          None
# 63                    CRIMINAL MISCHIEF,UNCLASSIFIED 4          None
# 64   LARCENY,GRAND BY CREDIT CARD ACCT COMPROMISE-E...          None
# 65                                WEAPONS POSSESSION 3          None
# 66               LARCENY,GRAND FROM EATERY, UNATTENDED          None
# 67                  ROBBERY,PERSONAL ELECTRONIC DEVICE          None
# 68                        ASSAULT POLICE/PEACE OFFICER          None
# 69               ASSAULT OTHER PUBLIC SERVICE EMPLOYEE          None
# 70                               LARCENY,GRAND OF BOAT          None
# 71                                  SUPP. ACT TERR 2ND          None
# 72                           MAKING TERRORISTIC THREAT          None
# 73                      FORGERY,ETC.,UNCLASSIFIED-FELO          None
# 74                      LARCENY,PETIT BY ACQUIRING LOS          None
# 75                   ROBBERY,LICENSED FOR HIRE VEHICLE          None
# 76               LARCENY,GRAND BY THEFT OF CREDIT CARD          None
# 77                             LARCENY, GRAND OF MOPED          None
# 78                                    ROBBERY,DWELLING          None
# 79                                            SODOMY 1          None
# 80                        AGGRAVATED CRIMINAL CONTEMPT          None
# 81                           BURGLARY,COMMERCIAL,NIGHT          None
# 82                     ROBBERY,RESIDENTIAL COMMON AREA          None
# 83                                     LEWDNESS,PUBLIC          None
# 84                      PUBLIC ADMINISTRATION,UNCLASSI          None
# 85                           FORGERY,M.V. REGISTRATION          None
# 86   LARCENY,GRAND BY BANK ACCT COMPROMISE-REPRODUC...          None
# 87                                 ROBBERY,CAR JACKING          None
# 88                          LARCENY,PETIT BY CHECK USE          None
# 89                      CONTROLLED SUBSTANCE,INTENT TO          None
# 90                             BURGLARY,COMMERCIAL,DAY          None
# 91           LARCENY,GRAND FROM NIGHT CLUB, UNATTENDED          None
# 92                       BRIBERY,PUBLIC ADMINISTRATION          None
# 93                         LARCENY,GRAND OF MOTORCYCLE          None
# 94         LARCENY,GRAND FROM RETAIL STORE, UNATTENDED          None
# 95   LARCENY,GRAND OF VEHICULAR/MOTORCYCLE ACCESSORIES          None
# 96                           FALSE REPORT UNCLASSIFIED          None
# 97                             ROBBERY,DELIVERY PERSON          None
# 98                                      ABANDON ANIMAL          None
# 99                                   CONTEMPT,CRIMINAL          None
# 100   LARCENY,GRAND BY OPEN/COMPROMISE CELL PHONE ACCT          None
# 101                          TRESPASS 4,CRIMINAL SUB 2          None
# 102                           CUSTODIAL INTERFERENCE 2          None
# 103                       STOLEN PROPERTY 3,POSSESSION          None
# 104            LARCENY,GRAND FROM PERSON, BAG OPEN/DIP          None
# 105  LARCENY,GRAND BY BANK ACCT COMPROMISE-UNAUTHOR...          None
# 106  LARCENY,GRAND FROM RESIDENCE/BUILDING,UNATTEND...          None
# 107                                             RAPE 2          None
# 108  LARCENY,GRAND FROM PERSON,LUSH WORKER(SLEEPING...          None
# 109                        BURGLARY,UNCLASSIFIED,NIGHT          None
# 110                              CAUSE SPI/KILL ANIMAL          None
# 111                             LARCENY,GRAND OF TRUCK          None
# 112                               ROBBERY, CHAIN STORE          None
# 113                            RECKLESS ENDANGERMENT 2          None
# 114                     LARCENY, GRAND OF AUTO - ATTEM          None
# 115                      TORTURE/INJURE ANIMAL CRUELTY          None
# 116                     NY STATE LAWS,UNCLASSIFIED VIO          None
# 117                      MISCHIEF, CRIMINAL 4, BY FIRE          None
# 118                     ARSON, MOTOR VEHICLE 1 2 3 & 4          None
# 119                      SEXUAL MISCONDUCT,INTERCOURSE          None
# 120                     STOLEN PROPERTY-MOTOR VEH 2ND,          None
# 121           LARCENY,GRAND FROM RESIDENCE, UNATTENDED          None
# 122                     ADM.CODE,UNCLASSIFIED MISDEMEA          None
# 123                     NY STATE LAWS,UNCLASSIFIED MIS          None
# 124                                   CANNABIS SALE, 3          None
# 125                LARCENY,GRAND FROM BOAT, UNATTENDED          None
# 126                                   FALSE ALARM FIRE          None
# 127  LARCENY,GRAND FROM RESIDENCE/BUILDING,UNATTEND...          None
# 128                LARCENY,GRAND FROM PIER, UNATTENDED          None
# 129                        CONTROLLED SUBSTANCE,SALE 1          None
# 130                     IMPERSONATION 2, PUBLIC SERVAN          None
# 131                                       KIDNAPPING 2          None
# 132                       GAMBLING, DEVICE, POSSESSION          None
# 133                                      CANNABIS SALE          None
# 134                               ACCOSTING,FRAUDULENT          None
# 135                               DIS. CON.,AGGRAVATED          None
# 136                                 BAIL JUMPING 1 & 2          None
# 137                                     BAIL JUMPING 3          None
# 138                              CHILD,ALCOHOL SALE TO          None
# 139  LARCENY,GRAND FROM PERSON,PERSONAL ELECTRONIC ...          None
# 140                                   ROBBERY,CLOTHING          None
# 141                     CONTROLLED SUBSTANCE, INTENT T          None
# 142                            AGGRAVATED HARASSMENT 1          None
# 143                                             RAPE 3          None
# 144                              ROBBERY,HOME INVASION          None
# 145                     LARCENY,GRAND BY DISHONEST EMP          None
# 146                     BURGLARY,COMMERCIAL,UNKNOWN TI          None
# 147                         UNAUTHORIZED USE VEHICLE 2          None
# 148                     ADM.CODE,UNCLASSIFIED VIOLATIO          None
# 149                                  FALSE REPORT BOMB          None
# 150                                TRESPASS 1,CRIMINAL          None
# 151                                       PROSTITUTION          None
# 152                                         ESCAPE 2,1          None
# 153                                 BURGLARY,TRUCK DAY          None
# 154                     PROSTITUTION, PATRONIZING 4, 3          None
# 155                                    CRIM POS WEAP 4          None
# 156                                           JOSTLING          None
# 157                     LARCENY,GRAND FROM PERSON,PURS          None
# 158                             MENACING,PEACE OFFICER          None
# 159                         IMITATION PISTOL/AIR RIFLE          None
# 160                     MENACING 1ST DEGREE (VICT PEAC          None
# 161           UNLAWFUL DISCLOSURE OF AN INTIMATE IMAGE          None
# 162                     OBSCENE MATERIAL - UNDER 17 YE          None
# 163                                            TAX LAW          None
# 164                        BURGLARS TOOLS,UNCLASSIFIED          None
# 165                     FORGERY-ILLEGAL POSSESSION,VEH          None
# 166                      BURGLARY,UNCLASSIFIED,UNKNOWN          None
# 167                           LARCENY,PETIT FROM TRUCK          None
# 168             LEAVING THE SCENE OF AN ACCIDENT (SPI)          None
# 169                            LARCENY,PETIT FROM PIER          None
# 170                                    SEX TRAFFICKING          None
# 171                     COURSE OF SEXUAL CONDUCT AGAIN          None
# 172                          ROBBERY,NECKCHAIN/JEWELRY          None
# 173                            TAMPERING 3,2, CRIMINAL          None
# 174                     ALCOHOLIC BEVERAGES,PUBLIC CON          None
# 175                                    ROBBERY,BICYCLE          None
# 176                     RECKLESS ENDANGERMENT OF PROPE          None
# 177                     MISCHIEF, CRIMINAL 3&2, BY FIR          None
# 178       LARCENY,GRAND BY IDENTITY THEFT-UNCLASSIFIED          None
# 179                          BURGLARY,UNCLASSIFIED,DAY          None
# 180                                       AIRPOLLUTION          None
# 181                                  CHILD ABANDONMENT          None
# 182                       BURGLARY, TRUCK UNKNOWN TIME          None
# 183                            IMPRISONMENT 1,UNLAWFUL          None
# 184                          TERRORISM PROVIDE SUPPORT          None
# 185                     AGRICULTURE & MARKETS LAW,UNCL          None
# 186                     LARCENY,PETIT BY DISHONEST EMP          None
# 187                          COMPUTER TAMPER/TRESSPASS          None
# 188                                     PERJURY 3,ETC.          None
# 189                                            ARSON 1          None
# 190                                FALSE REPORT 1,FIRE          None
# 191                                 DRUG, INJECTION OF          None
# 192                     LARCENY, PETIT OF AUTO - ATTEM          None
# 193                                         COERCION 2          None
# 194                           SOLICITATION 4, CRIMINAL          None
# 195                        ROBBERY,PUBLIC PLACE INSIDE          None
# 196                      MISCHIEF 1,CRIMINAL,EXPLOSIVE          None
# 197                                           SODOMY 3          None
# 198                           CUSTODIAL INTERFERENCE 1          None
# 199                               ROBBERY,LIQUOR STORE          None
# 200                     VEHICULAR ASSAULT (INTOX DRIVE          None
# 201                        LARCENY,PETIT OF MOTORCYCLE          None
# 202           INCOMPETENT PERSON,KNOWINGLY ENDANGERING          None
# 203                     ROBBERY,LICENSED MEDALLION CAB          None
# 204                        ASSAULT SCHOOL SAFETY AGENT          None
# 205                           CANNABIS POSSESSION, 2&1          None
# 206                            ROBBERY,OF TRUCK DRIVER          None
# 207                           N.Y.C. TRANSIT AUTH. R&R          None
# 208                     PROSTITUTION 3,PROMOTING BUSIN          None
# 209                                    FIREWORKS, SALE          None
# 210                    LARCENY,GRAND BY OPEN BANK ACCT          None
# 211                     MARIJUANA, POSSESSION 1, 2 & 3          None
# 212                                           ESCAPE 3          None
# 213                     ALCOHOLIC BEVERAGE CONTROL LAW          None
# 214                              ASSAULT TRAFFIC AGENT          None
# 215                     PROSTITUTION 4,PROMOTING&SECUR          None
# 216                     PUBLIC HEALTH LAW,UNCLASSIFIED          None
# 217                               EXPOSURE OF A PERSON          None
# 218                                    PERJURY 2,1,ETC          None
# 219                             ROBBERY,BAR/RESTAURANT          None
# 220                     DRUG PARAPHERNALIA,   POSSESSE          None
# 221                     UNAUTH. SALE OF TRANS. SERVICE          None
# 222                     USE OF A CHILD IN A SEXUAL PER          None
# 223                     GAMBLING 1,PROMOTING,BOOKMAKIN          None
# 224                              SALE SCHOOL GROUNDS 4          None
# 225                                           SODOMY 2          None
# 226                     THEFT,RELATED OFFENSES,UNCLASS          None
# 227                   DISSEMINATING A FALSE SEX OFFEND          None
# 228               LARCENY,GRAND FROM TRUCK, UNATTENDED          None
# 229                               ROBBERY,ATM LOCATION          None
# 230              END WELFARE VULNERABLE ELDERLY PERSON          None
# 231                       LABOR LAW,EMPLOYING CHILDREN          None
# 232                                      BRIBERY,FRAUD          None
# 233                     NUISANCE,CRIMINAL,UNCLASSIFIED          None
# 234                                 BRIBERY,COMMERCIAL          None
# 235                              HARASSMENT,SUBD 3,4,5          None
# 236                                          ASSAULT 3          None
# 237                     LARCENY,PETIT FROM BUILDING,UN          None
# 238                                CRIMINAL CONTEMPT 1          None
# 239              LARCENY,GRAND FROM VEHICLE/MOTORCYCLE          None
# 240   LARCENY,GRAND BY FALSE PROMISE-IN PERSON CONTACT          None
# 241                         LARCENY,GRAND BY EXTORTION          None
# 242                       ROBBERY,BEGIN AS SHOPLIFTING          None
# 243                                CANNABIS POSSESSION          None
# 244       LARCENY,GRAND BY OPEN CREDIT CARD (NEW ACCT)          None
# 245                         CHILD, ENDANGERING WELFARE          None
# 246                     BURGLARY,RESIDENCE,UNKNOWN TIM          None
# 247                         CRIMINAL POSSESSION WEAPON          None
# 248                             BURGLARY,RESIDENCE,DAY          None
# 249                            RECKLESS ENDANGERMENT 1          None
# 250                     CRIMINAL MISCHIEF 4TH, GRAFFIT          None
# 251                                    RIOT 2/INCITING          None
# 252                     ROBBERY,POCKETBOOK/CARRIED BAG          None
# 253                                     RAPE 1,ATTEMPT          None
# 254                     THEFT OF SERVICES, UNCLASSIFIE          None
# 255                     LARCENY,PETIT OF VEHICLE ACCES          None
# 256                           BURGLARY,RESIDENCE,NIGHT          None
# 257                                  ROBBERY,HIJACKING          None
# 258                            FORGERY,DRIVERS LICENSE          None
# 259                              LARCENY,PETIT OF AUTO          None
# 260                    ROBBERY,COMMERCIAL UNCLASSIFIED          None
# 261                     PROMOTING A SEXUAL PERFORMANCE          None
# 262       LARCENY,GRAND BY BANK ACCT COMPROMISE-TELLER          None
# 263                       CONTROLLED SUBSTANCE, SALE 4          None
# 264                                   ROBBERY,PHARMACY          None
# 265                       CONTROLLED SUBSTANCE, SALE 5          None
# 266                   ROBBERY,BODEGA/CONVENIENCE STORE          None
# 267                            LARCENY,PETIT FROM BOAT          None
# 268                                   RECKLESS DRIVING          None
# 269                                SALE SCHOOL GROUNDS          None
# 270                        CRIMINAL DISPOSAL FIREARM 1          None
# 271                              ENTERPRISE CORRUPTION          None
# 272                ROBBERY,UNLICENSED FOR HIRE VEHICLE          None
# 273                     UNLAWFUL POSS. WEAPON UPON SCH          None
# 274                                    CONSPIRACY 2, 1          None
# 275                           LARCENY,GRAND OF BICYCLE          None
# 265                            None    None  None
# 266                            None    None  None
# 267                            None    None  None
# 268                            None    None  None
# 269                            None    None  None
# 270                            None    None  None
# 271                            None    None  None
# 272                            None    None  None
# 273                            None    None  None
# 274                            None    None  None
# 275                            None    None  None
# 276                            None    None  None
# 277                            None    None  None
# 278                            None    None  None
# 279                            None    None  None
# 280                            None    None  None
# 281                            None    None  None
# 282                            None    None  None
# 283                            None    None  None
# 284                            None    None  None
# 285                            None    None  None
# 286                            None    None  None
# 287                            None    None  None
# 288                            None    None  None
# 289                            None    None  None
# 290                            None    None  None
# 291                            None    None  None
# 292                            None    None  None
# 293                            None    None  None
# 294                            None    None  None
# 295                            None    None  None
# 296                            None    None  None
# 297                            None    None  None
# 298                            None    None  None
# 299                            None    None  None
# 300                            None    None  None
# 301                            None    None  None
# 302                            None    None  None
# 303                            None    None  None
# 304                            None    None  None
# 305                            None    None  None
# 306                            None    None  None
# 307                            None    None  None
# 308                            None    None  None
# 309                            None    None  None
# 310                            None    None  None
# 311                            None    None  None
# 312                            None    None  None
# 313                            None    None  None
# 314                            None    None  None
# 315                            None    None  None
# 316                            None    None  None
# 317                            None    None  None
# 318                            None    None  None
# 319                            None    None  None
# 320                            None    None  None
# 321                            None    None  None
# 322                            None    None  None
# 323                            None    None  None
# 324                            None    None  None
# 325                            None    None  None
# 326                            None    None  None
# 327                            None    None  None
# 328                            None    None  None
# 329                            None    None  None
# 330                            None    None  None
# 331                            None    None  None
# 332                            None    None  None
# 333                            None    None  None
# 334                            None    None  None
# 335                            None    None  None
# 336                            None    None  None
# 337                            None    None  None
# 338                            None    None  None
# 339                            None    None  None
# 340                            None    None  None
# 341                            None    None  None
# 342                            None    None  None
# 343                            None    None  None
# 344                            None    None  None
# 345                            None    None  None
# 346                            None    None  None
# 347                            None    None  None
# 348                            None    None  None
# 349                            None    None  None
# 350                            None    None  None
# 351                            None    None  None
# 352                            None    None  None
# 353                            None    None  None
# 354                            None    None  None
# 355                            None    None  None
# 356                            None    None  None

# %%
#case 1 : simplified with less then 5 categories
#before_labeling_case_1 = df.copy(deep=True)
#case 1 : extended description of agression

before_labeling_case_2 = df.copy(deep=True)

# %%
# prompt: encode all columns 0 value to 0 label, all other labels start from 1 , don't encode ['LAW_CAT_CD', 'VIC_AGE_GROUP', 'SUSP_AGE_GROUP', 'VIC_SEX', 'SUSP_SEX']

from sklearn.preprocessing import LabelEncoder

# Create a LabelEncoder object
label_encoder = LabelEncoder()

columns_to_encode = [col for col in df.columns if col not in ['LAW_CAT_CD', 'VIC_AGE_GROUP', 'SUSP_AGE_GROUP', 'VIC_SEX', 'SUSP_SEX']]

for column in columns_to_encode:
  # Fit and transform the column
  df[column] = label_encoder.fit_transform(df[column])
  # Replace encoded 0 with 0 label, other labels start from 1


df.head()
# Out:
#    BORO_NM   LAW_CAT_CD  OFNS_DESC  PD_DESC VIC_AGE_GROUP  VIC_RACE VIC_SEX  \
# 0        2       FELONY         55      267         18-24         2       F
# 1        5  MISDEMEANOR         57      316         25-44         5       F
# 2        2    VIOLATION         27      122         25-44         2       F
# 3        5  MISDEMEANOR         51      197         25-44         2       F
# 4        5       FELONY         25      144           65+         6       M
#
#    Hour
# 0     4
# 1    13
# 2    16
# 3    10
# 4    12

# %%
# prompt: drop columns starting from CMPLNT

# Remove columns starting with 'CMPLNT'
#df = df.loc[:, ~df.columns.str.startswith('CMPLNT')]

# %%
# prompt: manually encode LAW_CAT_CD , VIC_AGE_GROUP

# Manually encode 'LAW_CAT_CD'
law_cat_mapping = {
    'FELONY': 3,
    'MISDEMEANOR': 2,
    'VIOLATION': 1
}
df['LAW_CAT_CD'] = df['LAW_CAT_CD'].map(law_cat_mapping)

# Manually encode 'VIC_AGE_GROUP'
vic_age_mapping = {
    '<18': 1,
    '18-24': 2,
    '25-44': 3,
    '45-64': 4,
    '65+': 5
}

susp_sex_mapping = {
    'U': 0,
    'M': 1,
    'F': 2
}

vic_sex_mapping = {
    'M':1,
    'F':2,
    'D':3,
    'E':4,
    'L':5

}

df['VIC_AGE_GROUP'] = df['VIC_AGE_GROUP'].map(vic_age_mapping)
#df['SUSP_AGE_GROUP'] = df['SUSP_AGE_GROUP'].map(vic_age_mapping)
df['VIC_SEX'] = df['VIC_SEX'].map(vic_sex_mapping)
#df['SUSP_SEX'] = df['SUSP_SEX'].map(susp_sex_mapping)
df.head()
# Out:
#    BORO_NM  LAW_CAT_CD  OFNS_DESC  PD_DESC  VIC_AGE_GROUP  VIC_RACE  VIC_SEX  \
# 0        2           3         55      267            2.0         2        2
# 1        5           2         57      316            3.0         5        2
# 2        2           1         27      122            3.0         2        2
# 3        5           2         51      197            3.0         2        2
# 4        5           3         25      144            5.0         6        1
#
#    Hour
# 0     4
# 1    13
# 2    16
# 3    10
# 4    12

# %%
# prompt: drop all UNKNOWN values from VIC_AGE_GROUP,  try to convert each row into integer, drop the row if  the number value is  negative or above 900, otherwise leave intact

# Drop rows where 'VIC_AGE_GROUP' is 'UNKNOWN'
#df = df[df['VIC_AGE_GROUP'] != 'UNKNOWN']
#df = df[df['SUSP_AGE_GROUP'] != 'UNKNOWN']

# Attempt to convert 'VIC_AGE_GROUP' to integer and handle errors
def convert_to_int_or_set_unknown(value):
  try:
    int_value = int(value)
    #if 0 <= int_value <= 900:
    return int_value
    # else:
    #   return None  # Replace with None or another appropriate value
  except (ValueError, TypeError):
    return 0  # Replace with 0 for all missed and unknown

df['VIC_AGE_GROUP'] = df['VIC_AGE_GROUP'].apply(convert_to_int_or_set_unknown)
#df['SUSP_AGE_GROUP'] = df['SUSP_AGE_GROUP'].apply(convert_to_int_or_set_unknown)
# Drop rows with None values in 'VIC_AGE_GROUP' (resulting from filtering)
#df.dropna(subset=['VIC_AGE_GROUP'], inplace=True)
#df.dropna(subset=['SUSP_AGE_GROUP'], inplace=True)
# Convert 'VIC_AGE_GROUP' to integer type
df['VIC_AGE_GROUP'] = df['VIC_AGE_GROUP'].astype(int)
#df['SUSP_AGE_GROUP'] = df['SUSP_AGE_GROUP'].astype(int)

df.head()
# Out:
#    BORO_NM  LAW_CAT_CD  OFNS_DESC  PD_DESC  VIC_AGE_GROUP  VIC_RACE  VIC_SEX  \
# 0        2           3         55      267              2         2        2
# 1        5           2         57      316              3         5        2
# 2        2           1         27      122              3         2        2
# 3        5           2         51      197              3         2        2
# 4        5           3         25      144              5         6        1
#
#    Hour
# 0     4
# 1    13
# 2    16
# 3    10
# 4    12

# %%
# prompt: show values distribution for VIC_AGE_GROUP with missed and NaN values

# Assuming 'before_dropna' DataFrame still contains the original data with missing values
print(df['VIC_AGE_GROUP'].value_counts(dropna=False))
#print(df['SUSP_AGE_GROUP'].value_counts(dropna=False))
# Out:
# VIC_AGE_GROUP
# 3    95280
# 0    90672
# 4    48600
# 2    22094
# 5    13646
# 1    11777
# Name: count, dtype: int64

# %%
# prompt:   encode OFNS_DESC with labelencoder specify CRM_ATPT_CPTD_CD as a target variable and others as predictors

# Apply LabelEncoder to 'OFNS_DESC'
# simple_offense_description = df.drop('PD_DESC',axis=1)
# extended_offense_description = df.drop('OFNS_DESC',axis=1)
# without_offense_description = df.drop(['PD_DESC','OFNS_DESC'],axis=1)
# #label_encoder = LabelEncoder()
# #simple_offense_description['OFNS_DESC'] = label_encoder.fit_transform(simple_offense_description['OFNS_DESC'])

# without_offense_description.head()

# %%
# prompt: drop VIC_RACE

# Assuming 'df' is your DataFrame
# if 'VIC_RACE' in df.columns:
#   df = df.drop('VIC_RACE', axis=1)
# df.head()

# %%
# prompt:  Count amount of each unique value for each column in df and show the distributions graphically as small plots close to each other 3 plots on each line

import matplotlib.pyplot as plt

# Calculate the number of unique values for each column
unique_counts = df.nunique()

# Create a figure and axes for the subplots
num_cols = 2
num_rows = (len(unique_counts) + num_cols - 1) // num_cols
fig, axes = plt.subplots(num_rows, num_cols, figsize=(15, 5 * num_rows))

# Iterate through the columns and create a plot for each
for i, (column, count) in enumerate(unique_counts.items()):
    row = i // num_cols
    col = i % num_cols

    # Create a bar plot for the unique value counts
    value_counts = df[column].value_counts()
    axes[row, col].bar(value_counts.index, value_counts.values)
    axes[row, col].set_title(f"Column: {column}")
    axes[row, col].tick_params(axis='x', rotation=45, labelsize=8)

    # Remove extra subplots if necessary
    if i >= len(unique_counts) - 1:
        for j in range(i + 1, num_rows * num_cols):
            row_extra = j // num_cols
            col_extra = j % num_cols
            fig.delaxes(axes[row_extra, col_extra])

# Adjust the layout and display the plots
plt.tight_layout()
plt.show()

# %%
# prompt: drop from VIC_SEX and SUSP_SEX rows with values except 1 or 2

# Filter the DataFrame to keep only rows where 'VIC_SEX' is 1 or 2
df = df[(df['VIC_SEX'] == 1) | (df['VIC_SEX'] == 2)]

# Filter the DataFrame to keep only rows where 'SUSP_SEX' is 1 or 2
#df = df[(df['SUSP_SEX'] == 1) | (df['SUSP_SEX'] == 2)]

# %%
# target_variable = 'VIC_SEX'
# #X = pd.DataFrame()
# #y = pd.DataFrame()
# indexes_to_keep = pd.Index([])
# # Calculate value counts for each column, exclude less than 5  for chi2
# for col in list(df.columns):
#   value_counts = df[col].value_counts()
#   # Filter out values with counts less than 5
#   print(value_counts[value_counts > 5].index)
#   #indexes_to_keep.union( value_counts[value_counts > 5].index)
#   # Create a new DataFrame 'X' excluding rows where 'PREM_TYP_DESC' has counts less than 5

# #X = df[df.isin(indexes_to_keep)].drop([target_variable], axis=1)
# #y = df[df.isin(indexes_to_keep)][target_variable]

# print(indexes_to_keep)

# %%
# prompt: determine classes of unique values for each df column. Eliminate those classes from df with less than 5 frequency

from collections import defaultdict

# Create a dictionary to store the classes and their frequencies for each column
class_frequencies = defaultdict(lambda: defaultdict(int))

# Iterate through each column in the DataFrame
for column in df.columns:
  # Iterate through each unique value in the column
  for value in df[column].unique():
    # Count the frequency of the unique value
    class_frequencies[column][value] = df[column].value_counts().get(value, 0)

# Create a new DataFrame to store the filtered data
filtered_df = df.copy()

# Iterate through each column in the DataFrame
for column in df.columns:
  # Iterate through the unique values and their frequencies for the current column
  for value, frequency in class_frequencies[column].items():
    # If the frequency is less than 5, drop rows with this value
    if frequency <= 5:
      filtered_df = filtered_df[filtered_df[column] != value]

# Print the DataFrame with filtered classes
display(filtered_df.head())
# Out:
#    BORO_NM  LAW_CAT_CD  OFNS_DESC  PD_DESC  VIC_AGE_GROUP  VIC_RACE  VIC_SEX  \
# 0        2           3         55      267              2         2        2
# 1        5           2         57      316              3         5        2
# 2        2           1         27      122              3         2        2
# 3        5           2         51      197              3         2        2
# 4        5           3         25      144              5         6        1
#
#    Hour
# 0     4
# 1    13
# 2    16
# 3    10
# 4    12

# %%
# Count amount of each unique value for each column in X
for col in filtered_df.columns:
  unique_values_count = filtered_df[col].value_counts()
  print(f"Unique values count for column '{col}':\n{unique_values_count}\n")
# Out:
# Unique values count for column 'BORO_NM':
# BORO_NM
# 1    55510
# 0    45512
# 4    45279
# 2    40092
# 5     8927
# 3      123
# Name: count, dtype: int64
#
# Unique values count for column 'LAW_CAT_CD':
# LAW_CAT_CD
# 2    86978
# 3    66645
# 1    41820
# Name: count, dtype: int64
#
# Unique values count for column 'OFNS_DESC':
# OFNS_DESC
# 27    41644
# 5     30736
# 51    25012
# 25    19486
# 10    13612
# 18    13236
# 41     8912
# 36     7413
# 56     7152
# 26     6405
# 57     4626
# 62     3678
# 7      3205
# 42     1776
# 59     1442
# 53      929
# 22      832
# 55      813
# 44      678
# 13      591
# 11      569
# 60      412
# 52      291
# 20      287
# 0       265
# 47      258
# 4       189
# 29      182
# 37      172
# 12      151
# 49      144
# 45       84
# 33       62
# 31       41
# 9        33
# 6        32
# 23       22
# 16       16
# 39       12
# 28       11
# 14        9
# 54        8
# 32        8
# 1         7
# Name: count, dtype: int64
#
# Unique values count for column 'PD_DESC':
# PD_DESC
# 123    32080
# 18     23305
# 17     10624
# 122     9564
# 8       8363
#        ...
# 171        6
# 56         6
# 23         6
# 70         6
# 305        6
# Name: count, Length: 218, dtype: int64
#
# Unique values count for column 'VIC_AGE_GROUP':
# VIC_AGE_GROUP
# 3    93695
# 4    48398
# 2    21798
# 5    13626
# 1    11746
# 0     6180
# Name: count, dtype: int64
#
# Unique values count for column 'VIC_RACE':
# VIC_RACE
# 2    64166
# 7    48571
# 6    35911
# 1    20916
# 5    12578
# 3    12106
# 0     1183
# 4       12
# Name: count, dtype: int64
#
# Unique values count for column 'VIC_SEX':
# VIC_SEX
# 2    102432
# 1     93011
# Name: count, dtype: int64
#
# Unique values count for column 'Hour':
# Hour
# 15    11616
# 18    11350
# 17    11334
# 12    11245
# 16    11110
# 19    10773
# 14    10547
# 20    10416
# 21     9335
# 13     9312
# 0      8817
# 22     8711
# 11     8392
# 10     8278
# 23     7676
# 9      7653
# 8      7612
# 1      5897
# 2      5139
# 7      5113
# 3      4527
# 4      3945
# 6      3505
# 5      3140
# Name: count, dtype: int64

# %%
# Specify target variable

target_variable = 'VIC_SEX'
test_size = 0.3

from sklearn.model_selection import train_test_split

X = filtered_df.drop([target_variable], axis=1).copy(deep=True)  # Predictors
y = filtered_df[target_variable].copy(deep=True)  # Target variable

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=test_size)

X = X_train.copy(deep=True)
y = y_train.copy(deep=True)

# %%
#X.head()

# %%
# prompt: count amount of each unique value for y

unique_values_count = y.value_counts()
print("Balance of a target variable {}".format(target_variable))
print(unique_values_count)
# Out:
# Balance of a target variable VIC_SEX
# VIC_SEX
# 2    71794
# 1    65016
# Name: count, dtype: int64

# %%
# prompt: plot a histogram of a y dataframe, susbscribe 1 as M , 2 as F. Calculate the ratio of one to another and display it above the histogram

import matplotlib.pyplot as plt

# Calculate value counts for y
value_counts = y.value_counts()

# Create a dictionary to map values to labels
labels = {1: 'M', 2: 'F'}

# Rename the index of value_counts using the labels dictionary
value_counts.rename(index=labels, inplace=True)


# Calculate the ratio of M to F
ratio_M_to_F = value_counts.get('M', 0) / value_counts.get('F', 1)

# Create the histogram
plt.hist(y, bins=[0.5, 1.5, 2.5], rwidth=0.8)
plt.xlabel('VIC_SEX')
plt.ylabel('Frequency')
plt.title('Histogram of VIC_SEX (M/F Ratio: {:.2f})'.format(ratio_M_to_F))

# Customize the x-axis ticks
plt.xticks([1, 2], ['M', 'F'])
plt.show()

# %%
# prompt: drop PD_DESC and LAW_CAT_CD

if 'PD_DESC' in X.columns:
  X = X.drop('PD_DESC', axis=1)

if 'LAW_CAT_CD' in X.columns:
  X = X.drop('LAW_CAT_CD', axis=1)

X.head()
# Out:
#    BORO_NM  OFNS_DESC  VIC_AGE_GROUP  VIC_RACE  Hour
# 0        2         55              2         2     4
# 1        5         57              3         5    13
# 2        2         27              3         2    16
# 3        5         51              3         2    10
# 4        5         25              5         6    12

# %%
#from sklearn.svm import LinearSVC

import warnings

warnings.filterwarnings("ignore")

from sklearn.feature_selection import SelectFromModel
from sklearn.svm import SVC, LinearSVC
# print("before LinearSVC:")
# print(X.shape)
lsvc = LinearSVC(C=0.01, penalty="l1", dual=False).fit(X, y)
#rbf_svc = SVC(kernel='rbf').fit(X, y)
model = SelectFromModel(lsvc, prefit=True)
#model = SelectFromModel(rbf_svc, prefit=True)
X_lsvc= model.transform(X)
# Get the indices of the selected features
selected_features_indices = model.get_support(indices=True)
# Get the names of the selected features
selected_features_lsvc = X.columns[selected_features_indices]
# print("after RBF SVC:")
# print(X_lsvc.shape)

print("Selected features:", list(selected_features_lsvc))
print("Eliminated features:", list(set(X.columns)-set(selected_features_lsvc)))
# Out:
# Selected features: ['BORO_NM', 'OFNS_DESC', 'VIC_AGE_GROUP', 'Hour']
# Eliminated features: ['VIC_RACE']

# %%
print("ExtraTreesClassifier feature selection:\n")
from sklearn.ensemble import ExtraTreesClassifier
from sklearn.feature_selection import SelectFromModel
selected_features_etc = []
for k in range(1,len(X.columns),1):
  # Create an instance of the ExtraTreesClassifier
  print("For {} features ExtraTreesClassifier:".format(k))
  clf = ExtraTreesClassifier(n_estimators=100,criterion ='entropy', max_features = k)
  clf = clf.fit(X, y)
  #clf.feature_importances_
  model = SelectFromModel(clf, prefit=True)
  X_etc = model.transform(X)
# Get the indices of the selected features
  selected_features_indices = model.get_support(indices=True)
# Get the names of the selected features
  selected_features = X.columns[selected_features_indices]
  print("Selected features:", list(selected_features))
  print("Eliminated features:", list(set(X.columns)-set(selected_features)))
  selected_features_etc.append(selected_features)
  print("\n")
# Out:
# ExtraTreesClassifier feature selection:
#
# For 1 features ExtraTreesClassifier:
# Selected features: ['OFNS_DESC', 'Hour']
# Eliminated features: ['BORO_NM', 'VIC_RACE', 'VIC_AGE_GROUP']
#
#
# For 2 features ExtraTreesClassifier:
# Selected features: ['OFNS_DESC', 'Hour']
# Eliminated features: ['BORO_NM', 'VIC_RACE', 'VIC_AGE_GROUP']
#
#
# For 3 features ExtraTreesClassifier:
# Selected features: ['OFNS_DESC', 'Hour']
# Eliminated features: ['BORO_NM', 'VIC_RACE', 'VIC_AGE_GROUP']
#
#
# For 4 features ExtraTreesClassifier:
# Selected features: ['OFNS_DESC', 'Hour']
# Eliminated features: ['BORO_NM', 'VIC_RACE', 'VIC_AGE_GROUP']

# %%
# prompt: use feature selection based on SelectKBest , print out selected feature names

from sklearn.feature_selection import SelectKBest, f_classif, chi2

# Assuming X and y are defined as in your previous code
selected_features_chi2 = []
# Select the top 10 features based on given statistic
for k in range(1,len(X.columns),1):
  selector = SelectKBest(chi2, k=k)
  X_kbest = selector.fit_transform(X, y)
  selected_features_indices = selector.get_support(indices=True)
  print("For {} features chi2 criteria:".format(k))
  # Get the names of the selected features
  selected_features = X.columns[selected_features_indices]

  print("Selected features:", list(selected_features))
  print("Eliminated features:", list(set(X.columns)-set(selected_features)))
  # Print the shape of the original and selected data
  #print("Original data shape:", X.shape)
  #print("Selected data shape:", X_kbest.shape)
  selected_features_chi2.append(selected_features)
  print("\n")
  # Get the indices of the selected features
# Out:
# For 1 features chi2 criteria:
# Selected features: ['BORO_NM']
# Eliminated features: ['VIC_RACE', 'Hour', 'OFNS_DESC', 'VIC_AGE_GROUP']
#
#
# For 2 features chi2 criteria:
# Selected features: ['BORO_NM', 'OFNS_DESC']
# Eliminated features: ['VIC_RACE', 'Hour', 'VIC_AGE_GROUP']
#
#
# For 3 features chi2 criteria:
# Selected features: ['BORO_NM', 'OFNS_DESC', 'VIC_AGE_GROUP']
# Eliminated features: ['VIC_RACE', 'Hour']
#
#
# For 4 features chi2 criteria:
# Selected features: ['BORO_NM', 'OFNS_DESC', 'VIC_AGE_GROUP', 'Hour']
# Eliminated features: ['VIC_RACE']

# %%
from sklearn.linear_model import Ridge
from sklearn.feature_selection import SequentialFeatureSelector
selected_features_forward_ridge = []
selected_features_backward_ridge = []

for k in range(1,len(X.columns),1):
  print("For {} features SequentialFeatureSelector:".format(k))
  num_fs = k  # Desired number of features
  # Forward selection
  ridge = Ridge(alpha=0.1)
  sfs_forward = SequentialFeatureSelector(ridge, n_features_to_select=num_fs, direction='forward')
  sfs_forward.fit(X, y)
  selected_features_forward = X.columns[sfs_forward.get_support()]
  eliminated_features_forward = list(set(X.columns) - set(selected_features_forward))

  print("Forward Selection Ridge Regression:")
  print("Selected features:", list(selected_features_forward))
  print("Eliminated features:", eliminated_features_forward)

  selected_features_forward_ridge.append(selected_features_forward)

  # Backward selection
  sfs_backward = SequentialFeatureSelector(ridge, n_features_to_select=num_fs, direction='backward')
  sfs_backward.fit(X, y)
  selected_features_backward = X.columns[sfs_backward.get_support()]
  eliminated_features_backward = list(set(X.columns) - set(selected_features_backward))

  print("Backward Selection Ridge Regression:")
  print("Selected features:", list(selected_features_backward))
  print("Eliminated features:", eliminated_features_backward)

  selected_features_backward_ridge.append(selected_features_backward)

  print("\n")
# Out:
# For 1 features SequentialFeatureSelector:
# Forward Selection Ridge Regression:
# Selected features: ['VIC_AGE_GROUP']
# Eliminated features: ['VIC_RACE', 'Hour', 'OFNS_DESC', 'BORO_NM']
# Backward Selection Ridge Regression:
# Selected features: ['VIC_AGE_GROUP']
# Eliminated features: ['VIC_RACE', 'Hour', 'OFNS_DESC', 'BORO_NM']
#
#
# For 2 features SequentialFeatureSelector:
# Forward Selection Ridge Regression:
# Selected features: ['VIC_AGE_GROUP', 'VIC_RACE']
# Eliminated features: ['Hour', 'OFNS_DESC', 'BORO_NM']
# Backward Selection Ridge Regression:
# Selected features: ['VIC_AGE_GROUP', 'VIC_RACE']
# Eliminated features: ['Hour', 'OFNS_DESC', 'BORO_NM']
#
#
# For 3 features SequentialFeatureSelector:
# Forward Selection Ridge Regression:
# Selected features: ['VIC_AGE_GROUP', 'VIC_RACE', 'Hour']
# Eliminated features: ['OFNS_DESC', 'BORO_NM']
# Backward Selection Ridge Regression:
# Selected features: ['VIC_AGE_GROUP', 'VIC_RACE', 'Hour']
# Eliminated features: ['OFNS_DESC', 'BORO_NM']
#
#
# For 4 features SequentialFeatureSelector:
# Forward Selection Ridge Regression:
# Selected features: ['OFNS_DESC', 'VIC_AGE_GROUP', 'VIC_RACE', 'Hour']
# Eliminated features: ['BORO_NM']
# Backward Selection Ridge Regression:
# Selected features: ['OFNS_DESC', 'VIC_AGE_GROUP', 'VIC_RACE', 'Hour']
# Eliminated features: ['BORO_NM']

# %%
# # prompt: apply from SequentialFeatureSelector to select features of X to targey y, use forward and backward methods, print selected and eliminated features , use ridge regression, specify num_fs variable for desired number of features
# #%pip install numba
# from numba import njit,prange
# numcols = len(X.columns)
# @njit(parallel=True) # speedup by running with parallel flag
# def compute_fs_in_parallel(k_min):
#   for k in prange( num_cols - 1,0,-1):
#       print("For {} features SequentialFeatureSelector:".format(k))
#       num_fs = k  # Desired number of features
#       ridge = Ridge()
#       sfs_forward = SequentialFeatureSelector(ridge, n_features_to_select=num_fs, direction='forward')
#       sfs_forward.fit(X, y)
#       selected_features_forward = X.columns[sfs_forward.get_support()]
#       eliminated_features_forward = list(set(X.columns) - set(selected_features_forward))

#       print("Forward Selection Ridge Regression:")
#       print("Selected features:", list(selected_features_forward))
#       print("Eliminated features:", eliminated_features_forward)

#       # Backward selection
#       sfs_backward = SequentialFeatureSelector(ridge, n_features_to_select=num_fs, direction='backward')
#       sfs_backward.fit(X, y)
#       selected_features_backward = X.columns[sfs_backward.get_support()]
#       eliminated_features_backward = list(set(X.columns) - set(selected_features_backward))

#       print("\nBackward Selection Ridge Regression:")
#       print("Selected features:", list(selected_features_backward))
#       print("Eliminated features:", eliminated_features_backward)

#       return

# compute_fs_in_parallel(1)

# %%
# prompt: apply from SequentialFeatureSelector to select features of X to targey y, use forward and backward methods, print selected and eliminated features , use logistic regression, specify num_fs variable for desired number of features

selected_features_forward_logistic = []
selected_features_backward_logistic = []

from sklearn.linear_model import LogisticRegression
from sklearn.feature_selection import SequentialFeatureSelector

for k in range(1,len(X.columns)-1,1):
  print("For {} features LogisticRegresson:".format(k))
  num_fs = k  # Desired number of features

# Forward selection
  logreg = LogisticRegression(max_iter=1000)  # Increase max_iter if needed
  sfs_forward = SequentialFeatureSelector(logreg, n_features_to_select=num_fs, direction='forward')
  sfs_forward.fit(X, y)
  selected_features_forward = X.columns[sfs_forward.get_support()]
  eliminated_features_forward = list(set(X.columns) - set(selected_features_forward))

  print("Forward Selection Logistic Regression:")
  print("Selected features:", list(selected_features_forward))
  print("Eliminated features:", eliminated_features_forward)

  selected_features_forward_logistic.append(selected_features_forward)

  # Backward selection
  sfs_backward = SequentialFeatureSelector(logreg, n_features_to_select=num_fs, direction='backward')
  sfs_backward.fit(X, y)
  selected_features_backward = X.columns[sfs_backward.get_support()]
  eliminated_features_backward = list(set(X.columns) - set(selected_features_backward))

  print("\nBackward Selection Logistic Regression:")
  print("Selected features:", list(selected_features_backward))
  print("Eliminated features:", eliminated_features_backward)

  selected_features_backward_logistic.append(selected_features_backward)

  print("\n")
# Out:
# For 1 features LogisticRegresson:
# Forward Selection Logistic Regression:
# Selected features: ['OFNS_DESC']
# Eliminated features: ['BORO_NM', 'VIC_RACE', 'Hour', 'VIC_AGE_GROUP']
#
# Backward Selection Logistic Regression:
# Selected features: ['VIC_AGE_GROUP']
# Eliminated features: ['VIC_RACE', 'Hour', 'OFNS_DESC', 'BORO_NM']
#
#
# For 2 features LogisticRegresson:
# Forward Selection Logistic Regression:
# Selected features: ['OFNS_DESC', 'VIC_AGE_GROUP']
# Eliminated features: ['VIC_RACE', 'Hour', 'BORO_NM']
#
# Backward Selection Logistic Regression:
# Selected features: ['OFNS_DESC', 'VIC_AGE_GROUP']
# Eliminated features: ['VIC_RACE', 'Hour', 'BORO_NM']
#
#
# For 3 features LogisticRegresson:
# Forward Selection Logistic Regression:
# Selected features: ['OFNS_DESC', 'VIC_AGE_GROUP', 'VIC_RACE']
# Eliminated features: ['Hour', 'BORO_NM']
#
# Backward Selection Logistic Regression:
# Selected features: ['OFNS_DESC', 'VIC_AGE_GROUP', 'VIC_RACE']
# Eliminated features: ['Hour', 'BORO_NM']

# %%
# prompt: inverse the order of each of selected_features lists into themselves

# selected_features_etc.reverse()
# selected_features_chi2.reverse()
# selected_features_forward_ridge.reverse()
# selected_features_backward_ridge.reverse()
# selected_features_forward_logistic.reverse()
# selected_features_backward_logistic.reverse()

# %%
# # prompt: Every list by the name of selected_features contains the same number of cells. Find similar values in all lists by the cell 0

# for k in range(0,len(selected_features_etc)):
#   common_features = set(selected_features_etc[k])
#   for lst in [selected_features_chi2, selected_features_forward_ridge, selected_features_backward_ridge,
#             selected_features_forward_logistic, selected_features_backward_logistic]:
#     if len(lst) > 0:
#       common_features = common_features.intersection(set(lst[k]))
# #
#   print("Common features for a number of {} features :".format(k+1), list(common_features))

# %%
X = filtered_df.drop([target_variable], axis=1).copy(deep=True)  # Predictors
y = filtered_df[target_variable].copy(deep=True)  # Target variable

# %%
# prompt: select common features  into X_sf

#X_sf = X[['VIC_AGE_GROUP', 'VIC_SEX', 'LOC_OF_OCCUR_DESC']]
#X_sf = X[[ 'VIC_SEX','VIC_AGE_GROUP','PREM_TYP_DESC','LAW_CAT_CD']]
X_sf = X[ [ 'OFNS_DESC'] ].copy(deep=True)

# %%
display (X_sf)
display(y)
# Out:
#         OFNS_DESC
# 0              55
# 1              57
# 2              27
# 3              51
# 4              25
# ...           ...
# 282064         36
# 282065          5
# 282066         25
# 282067         27
# 282068         27
#
# [195443 rows x 1 columns]
# 0         2
# 1         2
# 2         2
# 3         2
# 4         1
#          ..
# 282064    2
# 282065    1
# 282066    2
# 282067    2
# 282068    2
# Name: VIC_SEX, Length: 195443, dtype: int64

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X_sf, y, test_size=0.3)

# %%
# from sklearn.neural_network import MLPClassifier
# from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, classification_report, confusion_matrix


# mlp_gs = MLPClassifier(max_iter=10)
# parameter_space = {
#     'hidden_layer_sizes': [(10,),(20,),(30,)],
#     'activation': ['tanh', 'relu'],
#     'solver': ['sgd', 'adam'],
#     'alpha': [0.0001, 0.05],
#     'learning_rate': ['constant','adaptive'],
# }
# from sklearn.model_selection import GridSearchCV
# clf = GridSearchCV(mlp_gs, parameter_space, n_jobs=-1, cv=5)
# #clf.fit(X, y)

# # Initialize the MLP classifier
#mlp = MLPClassifier(hidden_layer_sizes=(100,), max_iter=1000, alpha=0.0001,
#                     solver='adam', verbose=10,  random_state=21,tol=0.00000001)

# Train the model
# clf.fit(X_train, y_train)
# print('Best parameters found:\n', clf.best_params_)

# %%
#X_train = X_sf.copy(deep=True)
#y_train = y.copy(deep=True)

# %%
# prompt: create a neural network classifier for X_sf and y


from sklearn.neural_network import MLPClassifier
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, classification_report, confusion_matrix

# Initialize the MLP classifier
mlp = MLPClassifier(hidden_layer_sizes=(100,),activation="relu", max_iter=1000, alpha=0.0001,
                     solver='adam', verbose=True,  random_state=251,tol=0.00000001)

# Train the model
mlp.fit(X_train, y_train)

# Make predictions on the test set
y_pred = mlp.predict(X_test)

# Evaluate the model
accuracy = accuracy_score(y_test, y_pred)
precision = precision_score(y_test, y_pred, average='weighted')
recall = recall_score(y_test, y_pred, average='weighted')
f1 = f1_score(y_test, y_pred, average='weighted')

print("Accuracy:", accuracy)
print("Precision:", precision)
print("Recall:", recall)
print("F1-score:", f1)

print(classification_report(y_test, y_pred))
print(confusion_matrix(y_test, y_pred))
# Out:
#
predict(X_test)

# Evaluate the model
accuracy = accuracy_score(y_test, y_pred)
precision = precision_score(y_test, y_pred, average='weighted')
recall = recall_score(y_test, y_pred, average='weighted')
f1 = f1_score(y_test, y_pred, average='weighted')

print("Accuracy:", accuracy)
print("Precision:", precision)
print("Recall:", recall)
print("F1-score:", f1)

# Print classification report
print("\nClassification Report:\n", classification_report(y_test, y_pred))
# Out:
# Accuracy: 0.547166271553562
# Precision: 0.5447319129903592
# Recall: 0.547166271553562
# F1-score: 0.5389874525004529
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            1       0.53      0.41      0.46     27980
#            2       0.56      0.67      0.61     30653
#
#     accuracy                           0.55     58633
#    macro avg       0.54      0.54      0.54     58633
# weighted avg       0.54      0.55      0.54     58633

# %%
# prompt: teach MLPClassifier with different activation functions and different solvers to search for best accuracy

from sklearn.neural_network import MLPClassifier
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import accuracy_score

# Define the parameter grid for GridSearchCV
parameter_space = {
    'hidden_layer_sizes': [(100,)],  # You can experiment with different layer sizes
    'activation': ['identity', 'logistic', 'tanh', 'relu'],
    'solver': ['lbfgs', 'sgd', 'adam']#,
    #'alpha': [0.0001, 0.05],
    #'learning_rate': ['constant', 'adaptive'],
}

# Create an MLPClassifier object
mlp = MLPClassifier(max_iter=1000)  # You can adjust max_iter as needed

# Create a GridSearchCV object
clf = GridSearchCV(mlp, parameter_space, n_jobs=-1, cv=5, scoring='accuracy')

# Fit the GridSearchCV object to the training data
clf.fit(X_train, y_train)

# Print the best parameters and the corresponding accuracy
print('Best parameters found:\n', clf.best_params_)

# Get the best estimator from GridSearchCV
best_mlp = clf.best_estimator_

# Make predictions on the test set using the best estimator
y_pred = best_mlp.predict(X_test)

# Evaluate the accuracy of the best estimator
accuracy = accuracy_score(y_test, y_pred)
print("Accuracy with best parameters:", accuracy)

# %%
# prompt: display the confusion matrix in a pretty way and name the classes from selected_features

import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import confusion_matrix

# Assuming y_test and y_pred are defined from your previous code

cm = confusion_matrix(y_test, y_pred)

# Get class names from your selected features (replace with your actual class names)
class_names = list(['M','F'])

plt.figure(figsize=(10, 7))
sns.heatmap(cm, annot=True, fmt='d', cmap='Greens', xticklabels=class_names, yticklabels=class_names)
plt.title('Confusion Matrix')
plt.ylabel('Actual Label')
plt.xlabel('Predicted Label')
plt.show()

# %%
# prompt: X_train.columns

print(X_train.columns)

# %%
# prompt: create an input_df variable for prediction with PD_DESC with all variety

# Create a DataFrame with all unique values from PD_DESC
unique_pd_desc = filtered_df['OFNS_DESC'].unique()
input_df = pd.DataFrame({'OFNS_DESC': unique_pd_desc})

# %%
# prompt: predict for each row in input_df, display as dataframe

# Make predictions using the trained model
predictions = mlp.predict(input_df)

# Create a new DataFrame with predictions
prediction_df = input_df.copy()
prediction_df['Predicted_VIC_SEX'] = predictions

# Map predicted values to labels
prediction_df['Predicted_VIC_SEX'] = prediction_df['Predicted_VIC_SEX'].map({1: 'M', 2: 'F'})

# Display the DataFrame with predictions
display(prediction_df)
# Out:
#     OFNS_DESC Predicted_VIC_SEX
# 0          55                 M
# 1          57                 M
# 2          27                 F
# 3          51                 F
# 4          25                 M
# 5          37                 F
# 6          10                 M
# 7          26                 F
# 8          41                 F
# 9          62                 M
# 10         18                 M
# 11         56                 M
# 12          5                 F
# 13         42                 F
# 14          7                 M
# 15         53                 M
# 16         22                 M
# 17         59                 M
# 18         36                 F
# 19         60                 M
# 20          4                 F
# 21         11                 M
# 22         44                 F
# 23         13                 M
# 24         12                 M
# 25         20                 M
# 26          0                 M
# 27         49                 F
# 28         33                 F
# 29         23                 M
# 30         14                 M
# 31         31                 F
# 32         45                 F
# 33         29                 F
# 34         54                 M
# 35          9                 M
# 36         39                 F
# 37         52                 M
# 38         16                 M
# 39          1                 F
# 40          6                 M
# 41         47                 F
# 42         28                 F
# 43         32                 F
